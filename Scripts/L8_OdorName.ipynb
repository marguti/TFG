# %%
# Importing libraries
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale

# %%
# Visualizing 6 decimals per value
pd.set_option('display.float_format', lambda x: '%.6f' % x)

# Reading data from csv
def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset

sensorama = load_dataset('sensorama_df.csv')

# %%
# Since odor name and canonical_smiles variables are strings, we change them to a numerical value
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(sensorama['canonical_smiles'])
sensorama['canonical_smiles']= label_encoder.transform(sensorama['canonical_smiles'])
label_encoder = preprocessing.LabelEncoder()
label_encoder.fit(sensorama['odor name'])
sensorama['odor name']= label_encoder.transform(sensorama['odor name'])

# %%
# Normalizing function
def standarize(x_train):
    mean = x_train.mean()
    std = x_train.std()
    x_train -= mean
    x_train /= std

# Normalizing data
s= sensorama.columns
s=s.drop(['odor level', 'cid','canonical_smiles', 'odor name'])
for c in s:
    standarize(sensorama[c])
# After normalizing the data, we have NaNs values, so we change them to 0
sensorama=sensorama.fillna(0)

# %%
# Creating a new dataframe with only those molecules of odor level = 1
sensorama_8 = []
for i in range (0,17994):
    if sensorama.loc[i,'odor level'] == 8:
        sensorama_8.append(sensorama.loc[i,:])
sensorama_8 = pd.DataFrame(sensorama_8)

# %%
X = sensorama_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama_8['odor name']

# %% [markdown]
# ### ALL ODOR NAMES

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  1.7391304347826086 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7','tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12','mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 
                 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn','khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn','khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 
                 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl',
               'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  3.4782608695652173 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 2.608695652173913 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 1.7391304347826086 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 1.7391304347826086 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 1.4492753623188406 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  9.565217391304348 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=18)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 4.3478260869565215 %

# %% [markdown]
# ### 25 MOST COMMON ODOR NAMES

# %%
sensorama_8 = sensorama_8.sort_values('odor name')

# %%
sensorama2_8=[]

for i in range(4, len(sensorama_8)-4):
    if sensorama_8.iloc[i,4] == sensorama_8.iloc[i+4,4] or sensorama_8.iloc[i,4] == sensorama_8.iloc[i-4,4]:
        sensorama2_8.append(sensorama_8.iloc[i,:]) 

sensorama2_8= pd.DataFrame(sensorama2_8)
sensorama2_8
# Out:
#                   cid  canonical_smiles     xlogp  odor level  odor name  \
# 16386  6441164.000000       1750.000000 -0.487506    8.000000  53.000000
# 12636   551316.000000       2215.000000 -0.974143    8.000000  53.000000
# 2680     10430.000000        754.000000 -1.113183    8.000000  53.000000
# 12126   520326.000000       1923.000000  0.277209    8.000000  53.000000
# 4933     24915.000000       2188.000000  0.485768    8.000000  53.000000
# ...               ...               ...       ...         ...        ...
# 10455   111727.000000        288.000000 -0.209428    8.000000 494.000000
# 17909 66823518.000000       1568.000000  1.459042    8.000000 494.000000
# 16693  6999041.000000       1481.000000 -1.599820    8.000000 494.000000
# 464       6184.000000       2598.000000 -0.696065    8.000000 494.000000
# 2648     10364.000000       1162.000000  0.207689    8.000000 494.000000
#
#            fsp3  small rings  arom rings  ring blocks  arom blocks  ...  \
# 16386  0.728406     3.434689   -0.631781     0.632666    -0.644741  ...
# 12636  0.936567     0.200130   -0.631781     0.632666    -0.644741  ...
# 2680   0.603735    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 12126  0.978124    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 4933  -0.519433     0.200130    1.183366     0.632666     1.285620  ...
# ...         ...          ...         ...          ...          ...  ...
# 10455  0.331554     0.200130   -0.631781     0.632666    -0.644741  ...
# 17909  0.603735    -0.878056   -0.631781     0.632666    -0.644741  ...
# 16693  0.728406     0.200130   -0.631781     0.632666    -0.644741  ...
# 464    0.728406    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 2648  -0.893823     0.200130    1.183366     0.632666     1.285620  ...
#
#           atsm4     atsm5     natom  arom bond  arom atom      apol     alogp  \
# 16386  0.623803  0.240994  0.226252   0.000000   0.000000  0.289164  0.017433
# 12636 -0.374812 -0.096254 -0.092074   0.000000   0.000000 -0.228672 -0.656448
# 2680  -1.402864 -0.912771 -1.259267   0.000000   0.000000 -1.452847 -0.904878
# 12126 -0.113632 -0.144128  0.332360   0.000000   0.000000  0.146060  0.512280
# 4933   0.623803  1.393145  0.756794   0.000000   0.000000  0.873775  0.496874
# ...         ...       ...       ...        ...        ...       ...       ...
# 10455  0.285048  0.144180  0.332360   0.000000   0.000000  0.273038 -0.001997
# 17909  0.532007  1.201665  1.393445   0.000000   0.000000  1.386350  1.514324
# 16693 -1.011177 -1.392573 -0.940942   0.000000   0.000000 -1.102261 -2.642912
# 464   -1.448762 -1.200546 -1.047050   0.000000   0.000000 -1.215967 -0.413571
# 2648   0.025084 -0.431902 -0.410399   0.000000   0.000000 -0.350399 -0.005466
#
#          alogp2       amr      acid
# 16386 -0.211686  0.107156 -0.161598
# 12636 -0.630351 -0.487532 -0.161598
# 2680  -0.733115 -1.696313  5.273531
# 12126  0.225927 -0.177236 -0.161598
# 4933   0.210643  1.102924 -0.161598
# ...         ...       ...       ...
# 10455 -0.226624  0.120831 -0.161598
# 17909  1.449749  1.202266 -0.161598
# 16693 -0.674849 -1.465149 -0.161598
# 464   -0.503023 -1.452390 -0.161598
# 2648  -0.229269 -0.135498 -0.161598
#
# [172 rows x 212 columns]

# %%
count=0
for i in range(1, len(sensorama2_8)):
    if sensorama2_8.iloc[i,4]!= sensorama2_8.iloc[i-1,4]:
        count = count +1
print(count)
# Out:
# 27

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  13.953488372093023 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7','tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 
                  'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  16.27906976744186 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 9.30232558139535 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 9.30232558139535 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 11.627906976744185 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 5.769230769230769 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  13.953488372093023 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 20.930232558139537 %

# %% [markdown]
# ### 15 MOST COMMON ODOR NAMES

# %%
sensorama_8 = sensorama_8 .sort_values('odor name')

# %%
sensorama2_8=[]

for i in range(6, len(sensorama_8)-6):
    if sensorama_8.iloc[i,4] == sensorama_8.iloc[i+6,4] or sensorama_8.iloc[i,4] == sensorama_8.iloc[i-6,4]:
        sensorama2_8.append(sensorama_8.iloc[i,:]) 

sensorama2_8= pd.DataFrame(sensorama2_8)
sensorama2_8
# Out:
#                  cid  canonical_smiles     xlogp  odor level  odor name  \
# 16386 6441164.000000       1750.000000 -0.487506    8.000000  53.000000
# 9024    93111.000000       2004.000000 -1.182702    8.000000  53.000000
# 977      7353.000000       2986.000000 -0.278948    8.000000 101.000000
# 13737 5282714.000000       2563.000000 -0.070389    8.000000 101.000000
# 10536  112492.000000       2433.000000 -0.139908    8.000000 110.000000
# ...              ...               ...       ...         ...        ...
# 1954     8129.000000       2905.000000 -0.070389    8.000000 494.000000
# 5499    33637.000000       1331.000000 -0.070389    8.000000 494.000000
# 4621    21458.000000        744.000000 -1.043663    8.000000 494.000000
# 10455  111727.000000        288.000000 -0.209428    8.000000 494.000000
# 16693 6999041.000000       1481.000000 -1.599820    8.000000 494.000000
#
#            fsp3  small rings  arom rings  ring blocks  arom blocks  ...  \
# 16386  0.728406     3.434689   -0.631781     0.632666    -0.644741  ...
# 9024  -0.252119     0.200130   -0.631781     0.632666    -0.644741  ...
# 977    0.884527    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 13737 -0.051447    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 10536 -0.311273    -0.878056   -0.631781    -1.106175    -0.644741  ...
# ...         ...          ...         ...          ...          ...  ...
# 1954   1.352513    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 5499  -1.455407     0.200130    1.183366     0.632666     1.285620  ...
# 4621  -0.519433    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 10455  0.331554     0.200130   -0.631781     0.632666    -0.644741  ...
# 16693  0.728406     0.200130   -0.631781     0.632666    -0.644741  ...
#
#           atsm4     atsm5     natom  arom bond  arom atom      apol     alogp  \
# 16386  0.623803  0.240994  0.226252   0.000000   0.000000  0.289164  0.017433
# 9024   0.299781 -0.672337 -0.940942   0.000000   0.000000 -1.006087 -1.427204
# 977   -0.528247 -0.720210 -0.304291   0.000000   0.000000 -0.493503  0.020973
# 13737 -0.988249 -0.720210 -0.516508   0.000000   0.000000 -0.631355  0.170585
# 10536 -1.034147 -0.768084 -0.304291   0.000000   0.000000 -0.394475  0.033672
# ...         ...       ...       ...        ...        ...       ...       ...
# 1954  -1.310557 -1.056392 -0.516508   0.000000   0.000000 -0.758333 -0.076109
# 5499  -0.527736 -0.912238 -1.047050   0.000000   0.000000 -0.989962 -0.761788
# 4621  -1.448762 -1.200546 -1.259267   0.000000   0.000000 -1.353819 -0.571511
# 10455  0.285048  0.144180  0.332360   0.000000   0.000000  0.273038 -0.001997
# 16693 -1.011177 -1.392573 -0.940942   0.000000   0.000000 -1.102261 -2.642912
#
#          alogp2       amr      acid
# 16386 -0.211686  0.107156 -0.161598
# 9024  -0.858545 -0.964556 -0.161598
# 977   -0.208954 -0.775895 -0.161598
# 13737 -0.088033 -0.713305  5.273531
# 10536 -0.199079 -0.335439 -0.161598
# ...         ...       ...       ...
# 1954  -0.282027 -1.073596 -0.161598
# 5499  -0.677321 -0.684692 -0.161598
# 4621  -0.588844 -1.379370 -0.161598
# 10455 -0.226624  0.120831 -0.161598
# 16693 -0.674849 -1.465149 -0.161598
#
# [96 rows x 212 columns]

# %%
count=0
for i in range(1, len(sensorama2_8)):
    if sensorama2_8.iloc[i,4]!= sensorama2_8.iloc[i-1,4]:
        count = count +1
print(count)
# Out:
# 14

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  16.666666666666664 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.22',
               'mden.23', 'mlogp', 'atom p', 'atom lc',
                  'khs.sch3', 'khs.dch2', 'khs.ssch2','khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.tn', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao','khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss','kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  12.5 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 33.33333333333333 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 29.166666666666668 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 29.166666666666668 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 17.24137931034483 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  29.166666666666668 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=20)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 37.5 %

# %% [markdown]
# ### 10 MOST COMMON ODOR NAMES

# %%
sensorama_8 = sensorama_8.sort_values('odor name')

# %%
sensorama2_8=[]

for i in range(7, len(sensorama_8)-7):
    if sensorama_8.iloc[i,4] == sensorama_8.iloc[i+7,4] or sensorama_8.iloc[i,4] == sensorama_8.iloc[i-7,4]:
        sensorama2_8.append(sensorama_8.iloc[i,:]) 

sensorama2_8= pd.DataFrame(sensorama2_8)
sensorama2_8
# Out:
#                  cid  canonical_smiles     xlogp  odor level  odor name  \
# 10536  112492.000000       2433.000000 -0.139908    8.000000 110.000000
# 1011     7363.000000        135.000000 -1.043663    8.000000 110.000000
# 9400   100968.000000       2548.000000  0.346729    8.000000 124.000000
# 13065 1549026.000000        395.000000  0.485768    8.000000 124.000000
# 13306 3018619.000000        833.000000  2.015198    8.000000 124.000000
# ...              ...               ...       ...         ...        ...
# 298      1068.000000       3382.000000 -1.321741    8.000000 475.000000
# 167       460.000000       3361.000000 -1.043663    8.000000 494.000000
# 1954     8129.000000       2905.000000 -0.070389    8.000000 494.000000
# 5499    33637.000000       1331.000000 -0.070389    8.000000 494.000000
# 4621    21458.000000        744.000000 -1.043663    8.000000 494.000000
#
#            fsp3  small rings  arom rings  ring blocks  arom blocks  ...  \
# 10536 -0.311273    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 1011  -1.642601     0.200130    1.183366     0.632666     1.285620  ...
# 9400   0.354017     0.200130   -0.631781     0.632666    -0.644741  ...
# 13065 -0.207567    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 13306  1.085199    -0.878056   -0.631781    -1.106175    -0.644741  ...
# ...         ...          ...         ...          ...          ...  ...
# 298    1.352513    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 167   -1.856378     0.200130    1.183366     0.632666     1.285620  ...
# 1954   1.352513    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 5499  -1.455407     0.200130    1.183366     0.632666     1.285620  ...
# 4621  -0.519433    -0.878056   -0.631781    -1.106175    -0.644741  ...
#
#           atsm4     atsm5     natom  arom bond  arom atom      apol     alogp  \
# 10536 -1.034147 -0.768084 -0.304291   0.000000   0.000000 -0.394475  0.033672
# 1011  -0.910578 -0.911157 -1.683701   0.000000   0.000000 -1.511674 -1.466064
# 9400   1.728918  2.641591  1.393445   0.000000   0.000000  1.414301  0.683058
# 13065 -0.297224  0.048433  0.544577   0.000000   0.000000  0.509918  0.599716
# 13306 -0.343122 -0.047314  1.499554   0.000000   0.000000  1.342273  1.977180
# ...         ...       ...       ...        ...        ...       ...       ...
# 298   -2.047480 -1.680881 -2.108136   0.000000   0.000000 -2.140362 -1.147617
# 167   -0.374812 -0.816491 -1.259267   0.000000   0.000000 -1.226841 -1.462317
# 1954  -1.310557 -1.056392 -0.516508   0.000000   0.000000 -0.758333 -0.076109
# 5499  -0.527736 -0.912238 -1.047050   0.000000   0.000000 -0.989962 -0.761788
# 4621  -1.448762 -1.200546 -1.259267   0.000000   0.000000 -1.353819 -0.571511
#
#          alogp2       amr      acid
# 10536 -0.199079 -0.335439 -0.161598
# 1011  -0.862968 -1.185350 -0.161598
# 9400   0.402545  1.312634 -0.161598
# 13065  0.314718  0.522644 -0.161598
# 13306  2.167675  0.952532 -0.161598
# ...         ...       ...       ...
# 298   -0.806686 -2.169589 -0.161598
# 167   -0.862567 -0.859816 -0.161598
# 1954  -0.282027 -1.073596 -0.161598
# 5499  -0.677321 -0.684692 -0.161598
# 4621  -0.588844 -1.379370 -0.161598
#
# [68 rows x 212 columns]

# %%
count=0
for i in range(1, len(sensorama2_8)):
    if sensorama2_8.iloc[i,4]!= sensorama2_8.iloc[i-1,4]:
        count = count +1
print(count)
# Out:
# 11

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  11.76470588235294 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.22',
               'mden.23', 'mlogp', 'atom p', 'atom lc',
                  'khs.sch3', 'khs.dch2', 'khs.ssch2','khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.tn', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao','khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss','kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  17.647058823529413 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 23.52941176470588 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 23.52941176470588 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 23.52941176470588 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 19.047619047619047 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  35.294117647058826 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=20)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 41.17647058823529 %

# %% [markdown]
# ### 7 MOST COMMON ODOR NAMES

# %%
sensorama_8 = sensorama_8.sort_values('odor name')

# %%
sensorama2_8=[]

for i in range(8, len(sensorama_8)-8):
    if sensorama_8.iloc[i,4] == sensorama_8.iloc[i+8,4] or sensorama_8.iloc[i,4] == sensorama_8.iloc[i-8,4]:
        sensorama2_8.append(sensorama_8.iloc[i,:]) 

sensorama2_8= pd.DataFrame(sensorama2_8)
sensorama2_8
# Out:
#                  cid  canonical_smiles     xlogp  odor level  odor name  \
# 9400   100968.000000       2548.000000  0.346729    8.000000 124.000000
# 13065 1549026.000000        395.000000  0.485768    8.000000 124.000000
# 3966    16441.000000        313.000000 -0.139908    8.000000 124.000000
# 9575   102861.000000       2544.000000 -0.070389    8.000000 124.000000
# 6213    61290.000000        972.000000  0.346729    8.000000 200.000000
# 13057 1549025.000000        395.000000  0.485768    8.000000 200.000000
# 7163    62341.000000        916.000000 -0.557026    8.000000 200.000000
# 7387    62660.000000        854.000000  1.041924    8.000000 200.000000
# 2554     9895.000000       1152.000000 -0.278948    8.000000 200.000000
# 8973    92606.000000       1092.000000  0.555287    8.000000 200.000000
# 5566    36081.000000        548.000000  0.416248    8.000000 200.000000
# 3140    12020.000000       1976.000000 -1.182702    8.000000 200.000000
# 4569    20995.000000       2538.000000  1.041924    8.000000 287.000000
# 12953  643731.000000       2119.000000 -0.417987    8.000000 287.000000
# 4393    19603.000000       2706.000000  1.320003    8.000000 287.000000
# 3568    13367.000000        293.000000 -1.113183    8.000000 287.000000
# 12377  526624.000000       1173.000000  0.138170    8.000000 287.000000
# 5087    27440.000000       2042.000000 -0.417987    8.000000 287.000000
# 911      7222.000000        115.000000 -0.557026    8.000000 287.000000
# 16532 6931359.000000       1644.000000 -1.391261    8.000000 287.000000
# 13381 3034267.000000        945.000000  0.694326    8.000000 371.000000
# 4865    24433.000000       2992.000000  0.485768    8.000000 371.000000
# 8491    86015.000000       1792.000000 -0.070389    8.000000 432.000000
# 13765 5283316.000000       2434.000000 -0.487506    8.000000 432.000000
# 16298 6438070.000000       2099.000000 -0.278948    8.000000 464.000000
# 5981    61096.000000       2895.000000  0.763846    8.000000 464.000000
# 1273     7651.000000        763.000000  0.346729    8.000000 464.000000
# 6509    61450.000000       3157.000000 -0.974143    8.000000 464.000000
# 16874 9856149.000000        211.000000  1.667601    8.000000 464.000000
# 13083 1549778.000000        387.000000  0.624807    8.000000 464.000000
# 6490    61446.000000        654.000000  0.902885    8.000000 464.000000
# 11887  442368.000000        379.000000  2.293277    8.000000 464.000000
# 14015 5352162.000000       2217.000000  1.041924    8.000000 464.000000
# 14906 5366038.000000       2935.000000  0.277209    8.000000 464.000000
# 14270 5355856.000000       2217.000000  1.041924    8.000000 464.000000
# 10094  108312.000000        963.000000  0.277209    8.000000 464.000000
# 2178     8375.000000        466.000000 -0.626545    8.000000 464.000000
# 9923   106756.000000       2640.000000  0.555287    8.000000 464.000000
# 2381     8842.000000        978.000000  0.277209    8.000000 464.000000
# 12881  641832.000000       2235.000000 -0.487506    8.000000 464.000000
# 3549    13233.000000       1120.000000  0.902885    8.000000 464.000000
# 13661 5281516.000000        379.000000  2.293277    8.000000 464.000000
# 14044 5352438.000000       2226.000000 -0.070389    8.000000 475.000000
# 298      1068.000000       3382.000000 -1.321741    8.000000 475.000000
# 167       460.000000       3361.000000 -1.043663    8.000000 494.000000
# 1954     8129.000000       2905.000000 -0.070389    8.000000 494.000000
# 5499    33637.000000       1331.000000 -0.070389    8.000000 494.000000
#
#            fsp3  small rings  arom rings  ring blocks  arom blocks  ...  \
# 9400   0.354017     0.200130   -0.631781     0.632666    -0.644741  ...
# 13065 -0.207567    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 3966  -0.519433     0.200130   -0.631781     0.632666    -0.644741  ...
# 9575   0.776702     0.200130   -0.631781     0.632666    -0.644741  ...
# 6213   0.331554    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 13057 -0.207567    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 7163  -1.268212     0.200130    1.183366     0.632666     1.285620  ...
# 7387  -1.054436     0.200130    1.183366     0.632666     1.285620  ...
# 2554   0.229345     0.200130   -0.631781     0.632666    -0.644741  ...
# 8973  -0.087388     0.200130   -0.631781     0.632666    -0.644741  ...
# 5566   1.040647     0.200130   -0.631781     0.632666    -0.644741  ...
# 3140  -0.145044    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 4569  -0.311273     0.200130    1.183366     0.632666     1.285620  ...
# 12953 -0.727594    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 4393  -0.008766     0.200130    1.183366     0.632666     1.285620  ...
# 3568  -1.143540    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 12377 -1.642601     1.278317    2.998513     2.371507     3.215981  ...
# 5087  -0.519433     0.200130    1.183366     0.632666     1.285620  ...
# 911   -2.391380     1.278317    2.998513     0.632666     1.285620  ...
# 16532 -0.519433     1.278317    1.183366     0.632666     1.285620  ...
# 13381 -1.405987     1.278317    2.998513     2.371507     3.215981  ...
# 4865  -1.030100     0.200130    1.183366     0.632666     1.285620  ...
# 8491  -0.519433    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 13765 -0.252119    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 16298  0.229345     0.200130   -0.631781     0.632666    -0.644741  ...
# 5981   1.012193    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 1273  -0.831300     0.200130    1.183366     0.632666     1.285620  ...
# 6509  -0.727594     0.200130    1.183366     0.632666     1.285620  ...
# 16874  0.603735    -0.878056   -0.631781     0.632666    -0.644741  ...
# 13083 -0.087388    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 6490  -0.394762     0.200130    1.183366     0.632666     1.285620  ...
# 11887 -0.644105    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14015  0.015569    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14906  0.229345    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14270  0.015569    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 10094 -0.519433     0.200130    1.183366     0.632666     1.285620  ...
# 2178  -1.923393     0.200130    1.183366     0.632666     1.285620  ...
# 9923   1.012193     0.200130   -0.631781     0.632666    -0.644741  ...
# 2381   0.603735    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 12881  0.817511    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 3549   1.352513     0.200130   -0.631781     0.632666    -0.644741  ...
# 13661 -0.644105    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14044  0.229345    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 298    1.352513    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 167   -1.856378     0.200130    1.183366     0.632666     1.285620  ...
# 1954   1.352513    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 5499  -1.455407     0.200130    1.183366     0.632666     1.285620  ...
#
#           atsm4     atsm5     natom  arom bond  arom atom      apol     alogp  \
# 9400   1.728918  2.641591  1.393445   0.000000   0.000000  1.414301  0.683058
# 13065 -0.297224  0.048433  0.544577   0.000000   0.000000  0.509918  0.599716
# 3966  -0.159019 -0.431902 -0.410399   0.000000   0.000000 -0.350399  0.152196
# 9575   0.853803  1.056978  0.969011   0.000000   0.000000  0.912590  0.147338
# 6213  -0.251326  0.096307  0.438469   0.000000   0.000000  0.327989  0.536845
# 13057 -0.297224  0.048433  0.544577   0.000000   0.000000  0.509918  0.599716
# 7163  -0.113121  0.096307 -0.516508   0.000000   0.000000 -0.405350 -0.647635
# 7387   0.347392  0.432488  0.544577   0.000000   0.000000  0.735923  0.567864
# 2554   0.255597  0.144180 -0.198182   0.000000   0.000000 -0.212547  0.249833
# 8973   0.439700  0.480895  0.544577   0.000000   0.000000  0.608945  0.722196
# 5566   0.439700  0.480895  0.756794   0.000000   0.000000  0.647760  0.413879
# 3140  -1.402864 -1.536727 -1.365376   0.000000   0.000000 -1.535748 -0.894469
# 4569  -0.849270 -0.575249 -0.516508   0.000000   0.000000 -0.315460  0.306181
# 12953 -1.034147 -0.768084 -0.516508   0.000000   0.000000 -0.532328  0.211528
# 4393  -0.757737 -0.479776  0.120143   0.000000   0.000000  0.107235  0.422554
# 3568  -1.678500 -1.680881 -2.002027   0.000000   0.000000 -1.958433 -0.845824
# 12377  2.578395  1.460508 -0.516508   0.000000   0.000000  0.056336 -1.148450
# 5087  -0.733731 -1.248419 -1.259267   0.000000   0.000000 -1.092173 -0.837844
# 911   -0.296159 -0.839599 -1.577593   0.000000   0.000000 -1.185938 -0.959560
# 16532 -0.224431 -0.791999 -0.940942   0.000000   0.000000 -0.845452 -1.558636
# 13381  2.811202  2.802265  1.605662   0.000000   0.000000  2.048953 -0.033501
# 4865   0.646289  0.808038  0.014035   0.000000   0.000000  0.097063 -0.761927
# 8491  -0.251837 -0.431902 -0.092074   0.000000   0.000000 -0.129645  0.130753
# 13765 -1.310557 -1.056392 -0.940942   0.000000   0.000000 -1.034038 -0.113096
# 16298 -0.205428 -0.239875 -0.092074   0.000000   0.000000 -0.129645  0.075585
# 5981  -0.343633 -0.287748  0.650686   0.000000   0.000000  0.465831  0.966323
# 1273   0.116880  0.384067  0.120143   0.000000   0.000000  0.234213  0.044497
# 6509  -0.481838 -0.192001 -0.516508   0.000000   0.000000 -0.504377 -1.331857
# 16874  0.623803  1.105385  1.499554   0.000000   0.000000  1.469251  1.666227
# 13083 -0.343122 -0.047314  0.756794   0.000000   0.000000  0.746787  0.812546
# 6490   0.992009  0.961231  1.075120   0.000000   0.000000  1.193546  0.817820
# 11887 -0.112609  0.048967  1.075120   0.000000   0.000000  1.165596  2.089945
# 14015  0.209187  0.576642  1.181228   0.000000   0.000000  1.149470  1.379076
# 14906 -0.481838 -0.192001  0.120143   0.000000   0.000000  0.008208  0.633649
# 14270  0.209187  0.576642  1.181228   0.000000   0.000000  1.149470  1.379076
# 10094 -0.204916 -0.143594  0.226252   0.000000   0.000000  0.289164  0.174680
# 2178  -0.159530 -0.224522 -1.153159   0.000000   0.000000 -1.044912 -1.428245
# 9923  -0.067223 -0.095721  0.438469   0.000000   0.000000  0.327989  0.605684
# 2381  -0.757737 -0.431902  0.226252   0.000000   0.000000  0.063158  0.416447
# 12881 -0.574145 -0.720210 -0.622616   0.000000   0.000000 -0.813284 -0.267913
# 3549   0.717920  2.358126  0.120143   0.000000   0.000000  0.559783 -0.214688
# 13661 -0.112609  0.048967  1.075120   0.000000   0.000000  1.165596  2.089945
# 14044 -0.481838 -0.192001  0.120143   0.000000   0.000000  0.008208  0.341224
# 298   -2.047480 -1.680881 -2.108136   0.000000   0.000000 -2.140362 -1.147617
# 167   -0.374812 -0.816491 -1.259267   0.000000   0.000000 -1.226841 -1.462317
# 1954  -1.310557 -1.056392 -0.516508   0.000000   0.000000 -0.758333 -0.076109
# 5499  -0.527736 -0.912238 -1.047050   0.000000   0.000000 -0.989962 -0.761788
#
#          alogp2       amr      acid
# 9400   0.402545  1.312634 -0.161598
# 13065  0.314718  0.522644 -0.161598
# 3966  -0.103437 -0.331972 -0.161598
# 9575  -0.107480  0.645351 -0.161598
# 6213   0.250534  0.173136 -0.161598
# 13057  0.314718  0.522644 -0.161598
# 7163  -0.626199 -0.115391 -0.161598
# 7387   0.281971  1.185509 -0.161598
# 2554  -0.019893 -0.343095 -0.161598
# 8973   0.444875  0.577343 -0.161598
# 5566   0.130134  0.278321 -0.161598
# 3140  -0.729364 -1.699834 -0.161598
# 4569   0.030275 -0.084142 -0.161598
# 12953 -0.053183 -0.399751 -0.161598
# 4393   0.138405  0.113954 -0.161598
# 3568  -0.711207 -1.884045 -0.161598
# 12377 -0.806892  0.982303 -0.161598
# 5087  -0.708117 -0.895207 -0.161598
# 911   -0.751998 -0.483534 -0.161598
# 16532 -0.870762 -0.789328 -0.161598
# 13381 -0.250472  3.033399 -0.161598
# 4865  -0.677375  0.445011 -0.161598
# 8491  -0.121204 -0.037739 -0.161598
# 13765 -0.308748 -1.074898 -0.161598
# 16298 -0.165973 -0.233918 -0.161598
# 5981   0.724451  0.128970 -0.161598
# 1273  -0.190602  0.496923 -0.161598
# 6509  -0.844811 -0.358549 -0.161598
# 16874  1.674734  1.288287 -0.161598
# 13083  0.545221  0.751145 -0.161598
# 6490   0.551194  1.402234 -0.161598
# 11887  2.357192  1.368033 -0.161598
# 14015  1.258183  1.126426 -0.161598
# 14906  0.350100 -0.095625 -0.161598
# 14270  1.258183  1.126426 -0.161598
# 10094 -0.084575  0.508583 -0.161598
# 2178  -0.858675 -0.669624 -0.161598
# 9923   0.320908 -0.014387 -0.161598
# 2381   0.132573 -0.121705 -0.161598
# 12881 -0.413918 -1.081532 -0.161598
# 3549  -0.378981  0.872099 -0.161598
# 13661  2.357192  1.368033 -0.161598
# 14044  0.062188 -0.099014 -0.161598
# 298   -0.806686 -2.169589 -0.161598
# 167   -0.862567 -0.859816 -0.161598
# 1954  -0.282027 -1.073596 -0.161598
# 5499  -0.677321 -0.684692 -0.161598
#
# [47 rows x 212 columns]

# %%
count=0
for i in range(1, len(sensorama2_8)):
    if sensorama2_8.iloc[i,4]!= sensorama2_8.iloc[i-1,4]:
        count = count +1
print(count)
# Out:
# 7

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  58.333333333333336 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.22',
               'mden.23', 'mlogp', 'atom p', 'atom lc',
                  'khs.sch3', 'khs.dch2', 'khs.ssch2','khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.tn', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao','khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss','kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  50.0 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 58.333333333333336 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 58.333333333333336 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 66.66666666666666 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 26.666666666666668 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  50.0 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=16)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 66.66666666666666 %

# %% [markdown]
# ### 5 MOST COMMON ODOR NAMES

# %%
sensorama_8= sensorama_8.sort_values('odor name')

# %%
sensorama2_8=[]

for i in range(9, len(sensorama_8)-9):
    if sensorama_8.iloc[i,4] == sensorama_8.iloc[i+9,4] or sensorama_8.iloc[i,4] == sensorama_8.iloc[i-9,4]:
        sensorama2_8.append(sensorama_8.iloc[i,:]) 

sensorama2_8= pd.DataFrame(sensorama2_8)
sensorama2_8
# Out:
#                  cid  canonical_smiles     xlogp  odor level  odor name  \
# 2123     8294.000000        414.000000  0.346729    8.000000 124.000000
# 14219 5354882.000000        404.000000  0.485768    8.000000 124.000000
# 8973    92606.000000       1092.000000  0.555287    8.000000 200.000000
# 2554     9895.000000       1152.000000 -0.278948    8.000000 200.000000
# 3140    12020.000000       1976.000000 -1.182702    8.000000 200.000000
# 278      1031.000000       3026.000000 -1.738859    8.000000 200.000000
# 7387    62660.000000        854.000000  1.041924    8.000000 200.000000
# 7163    62341.000000        916.000000 -0.557026    8.000000 200.000000
# 16532 6931359.000000       1644.000000 -1.391261    8.000000 287.000000
# 911      7222.000000        115.000000 -0.557026    8.000000 287.000000
# 5087    27440.000000       2042.000000 -0.417987    8.000000 287.000000
# 4393    19603.000000       2706.000000  1.320003    8.000000 287.000000
# 12953  643731.000000       2119.000000 -0.417987    8.000000 287.000000
# 4569    20995.000000       2538.000000  1.041924    8.000000 287.000000
# 13661 5281516.000000        379.000000  2.293277    8.000000 464.000000
# 3549    13233.000000       1120.000000  0.902885    8.000000 464.000000
# 12881  641832.000000       2235.000000 -0.487506    8.000000 464.000000
# 2381     8842.000000        978.000000  0.277209    8.000000 464.000000
# 9923   106756.000000       2640.000000  0.555287    8.000000 464.000000
# 2178     8375.000000        466.000000 -0.626545    8.000000 464.000000
# 10094  108312.000000        963.000000  0.277209    8.000000 464.000000
# 14270 5355856.000000       2217.000000  1.041924    8.000000 464.000000
# 14906 5366038.000000       2935.000000  0.277209    8.000000 464.000000
# 14015 5352162.000000       2217.000000  1.041924    8.000000 464.000000
# 11887  442368.000000        379.000000  2.293277    8.000000 464.000000
# 6490    61446.000000        654.000000  0.902885    8.000000 464.000000
# 13083 1549778.000000        387.000000  0.624807    8.000000 464.000000
# 16874 9856149.000000        211.000000  1.667601    8.000000 464.000000
# 6509    61450.000000       3157.000000 -0.974143    8.000000 464.000000
# 1273     7651.000000        763.000000  0.346729    8.000000 464.000000
# 5981    61096.000000       2895.000000  0.763846    8.000000 464.000000
# 16298 6438070.000000       2099.000000 -0.278948    8.000000 464.000000
# 464      6184.000000       2598.000000 -0.696065    8.000000 494.000000
# 16693 6999041.000000       1481.000000 -1.599820    8.000000 494.000000
#
#            fsp3  small rings  arom rings  ring blocks  arom blocks  ...  \
# 2123  -0.207567    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14219 -0.349086    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 8973  -0.087388     0.200130   -0.631781     0.632666    -0.644741  ...
# 2554   0.229345     0.200130   -0.631781     0.632666    -0.644741  ...
# 3140  -0.145044    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 278    1.352513    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 7387  -1.054436     0.200130    1.183366     0.632666     1.285620  ...
# 7163  -1.268212     0.200130    1.183366     0.632666     1.285620  ...
# 16532 -0.519433     1.278317    1.183366     0.632666     1.285620  ...
# 911   -2.391380     1.278317    2.998513     0.632666     1.285620  ...
# 5087  -0.519433     0.200130    1.183366     0.632666     1.285620  ...
# 4393  -0.008766     0.200130    1.183366     0.632666     1.285620  ...
# 12953 -0.727594    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 4569  -0.311273     0.200130    1.183366     0.632666     1.285620  ...
# 13661 -0.644105    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 3549   1.352513     0.200130   -0.631781     0.632666    -0.644741  ...
# 12881  0.817511    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 2381   0.603735    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 9923   1.012193     0.200130   -0.631781     0.632666    -0.644741  ...
# 2178  -1.923393     0.200130    1.183366     0.632666     1.285620  ...
# 10094 -0.519433     0.200130    1.183366     0.632666     1.285620  ...
# 14270  0.015569    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14906  0.229345    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 14015  0.015569    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 11887 -0.644105    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 6490  -0.394762     0.200130    1.183366     0.632666     1.285620  ...
# 13083 -0.087388    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 16874  0.603735    -0.878056   -0.631781     0.632666    -0.644741  ...
# 6509  -0.727594     0.200130    1.183366     0.632666     1.285620  ...
# 1273  -0.831300     0.200130    1.183366     0.632666     1.285620  ...
# 5981   1.012193    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 16298  0.229345     0.200130   -0.631781     0.632666    -0.644741  ...
# 464    0.728406    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 16693  0.728406     0.200130   -0.631781     0.632666    -0.644741  ...
#
#           atsm4     atsm5     natom  arom bond  arom atom      apol     alogp  \
# 2123   0.163289  0.672923  0.544577   0.000000   0.000000  0.509918  0.461831
# 14219 -0.435429 -0.095721  0.226252   0.000000   0.000000  0.190136  0.545034
# 8973   0.439700  0.480895  0.544577   0.000000   0.000000  0.608945  0.722196
# 2554   0.255597  0.144180 -0.198182   0.000000   0.000000 -0.212547  0.249833
# 3140  -1.402864 -1.536727 -1.365376   0.000000   0.000000 -1.535748 -0.894469
# 278   -1.863377 -1.680881 -1.789810   0.000000   0.000000 -2.037458 -1.342405
# 7387   0.347392  0.432488  0.544577   0.000000   0.000000  0.735923  0.567864
# 7163  -0.113121  0.096307 -0.516508   0.000000   0.000000 -0.405350 -0.647635
# 16532 -0.224431 -0.791999 -0.940942   0.000000   0.000000 -0.845452 -1.558636
# 911   -0.296159 -0.839599 -1.577593   0.000000   0.000000 -1.185938 -0.959560
# 5087  -0.733731 -1.248419 -1.259267   0.000000   0.000000 -1.092173 -0.837844
# 4393  -0.757737 -0.479776  0.120143   0.000000   0.000000  0.107235  0.422554
# 12953 -1.034147 -0.768084 -0.516508   0.000000   0.000000 -0.532328  0.211528
# 4569  -0.849270 -0.575249 -0.516508   0.000000   0.000000 -0.315460  0.306181
# 13661 -0.112609  0.048967  1.075120   0.000000   0.000000  1.165596  2.089945
# 3549   0.717920  2.358126  0.120143   0.000000   0.000000  0.559783 -0.214688
# 12881 -0.574145 -0.720210 -0.622616   0.000000   0.000000 -0.813284 -0.267913
# 2381  -0.757737 -0.431902  0.226252   0.000000   0.000000  0.063158  0.416447
# 9923  -0.067223 -0.095721  0.438469   0.000000   0.000000  0.327989  0.605684
# 2178  -0.159530 -0.224522 -1.153159   0.000000   0.000000 -1.044912 -1.428245
# 10094 -0.204916 -0.143594  0.226252   0.000000   0.000000  0.289164  0.174680
# 14270  0.209187  0.576642  1.181228   0.000000   0.000000  1.149470  1.379076
# 14906 -0.481838 -0.192001  0.120143   0.000000   0.000000  0.008208  0.633649
# 14015  0.209187  0.576642  1.181228   0.000000   0.000000  1.149470  1.379076
# 11887 -0.112609  0.048967  1.075120   0.000000   0.000000  1.165596  2.089945
# 6490   0.992009  0.961231  1.075120   0.000000   0.000000  1.193546  0.817820
# 13083 -0.343122 -0.047314  0.756794   0.000000   0.000000  0.746787  0.812546
# 16874  0.623803  1.105385  1.499554   0.000000   0.000000  1.469251  1.666227
# 6509  -0.481838 -0.192001 -0.516508   0.000000   0.000000 -0.504377 -1.331857
# 1273   0.116880  0.384067  0.120143   0.000000   0.000000  0.234213  0.044497
# 5981  -0.343633 -0.287748  0.650686   0.000000   0.000000  0.465831  0.966323
# 16298 -0.205428 -0.239875 -0.092074   0.000000   0.000000 -0.129645  0.075585
# 464   -1.448762 -1.200546 -1.047050   0.000000   0.000000 -1.215967 -0.413571
# 16693 -1.011177 -1.392573 -0.940942   0.000000   0.000000 -1.102261 -2.642912
#
#          alogp2       amr      acid
# 2123   0.176269  0.458751 -0.161598
# 14219  0.258784  0.256212 -0.161598
# 8973   0.444875  0.577343 -0.161598
# 2554  -0.019893 -0.343095 -0.161598
# 3140  -0.729364 -1.699834 -0.161598
# 278   -0.846534 -2.277771 -0.161598
# 7387   0.281971  1.185509 -0.161598
# 7163  -0.626199 -0.115391 -0.161598
# 16532 -0.870762 -0.789328 -0.161598
# 911   -0.751998 -0.483534 -0.161598
# 5087  -0.708117 -0.895207 -0.161598
# 4393   0.138405  0.113954 -0.161598
# 12953 -0.053183 -0.399751 -0.161598
# 4569   0.030275 -0.084142 -0.161598
# 13661  2.357192  1.368033 -0.161598
# 3549  -0.378981  0.872099 -0.161598
# 12881 -0.413918 -1.081532 -0.161598
# 2381   0.132573 -0.121705 -0.161598
# 9923   0.320908 -0.014387 -0.161598
# 2178  -0.858675 -0.669624 -0.161598
# 10094 -0.084575  0.508583 -0.161598
# 14270  1.258183  1.126426 -0.161598
# 14906  0.350100 -0.095625 -0.161598
# 14015  1.258183  1.126426 -0.161598
# 11887  2.357192  1.368033 -0.161598
# 6490   0.551194  1.402234 -0.161598
# 13083  0.545221  0.751145 -0.161598
# 16874  1.674734  1.288287 -0.161598
# 6509  -0.844811 -0.358549 -0.161598
# 1273  -0.190602  0.496923 -0.161598
# 5981   0.724451  0.128970 -0.161598
# 16298 -0.165973 -0.233918 -0.161598
# 464   -0.503023 -1.452390 -0.161598
# 16693 -0.674849 -1.465149 -0.161598
#
# [34 rows x 212 columns]

# %%
count=0
for i in range(1, len(sensorama2_8)):
    if sensorama2_8.iloc[i,4]!= sensorama2_8.iloc[i-1,4]:
        count = count +1
print(count)
# Out:
# 4

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  55.55555555555556 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.22',
               'mden.23', 'mlogp', 'atom p', 'atom lc',
                  'khs.sch3', 'khs.dch2', 'khs.ssch2','khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.tn', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao','khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss','kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  55.55555555555556 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 77.77777777777779 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 77.77777777777779 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 77.77777777777779 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 9.090909090909092 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  66.66666666666666 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,21):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 21), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=6)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 66.66666666666666 %

# %% [markdown]
# ### 3 MOST COMMON ODOR NAMES

# %%
sensorama_8 = sensorama_8.sort_values('odor name')

# %%
sensorama2_8=[]

for i in range(10, len(sensorama_8)-10):
    if sensorama_8.iloc[i,4] == sensorama_8.iloc[i+10,4] or sensorama_8.iloc[i,4] == sensorama_8.iloc[i-10,4]:
        sensorama2_8.append(sensorama_8.iloc[i,:]) 

sensorama2_8= pd.DataFrame(sensorama2_8)
sensorama2_8
# Out:
#                  cid  canonical_smiles     xlogp  odor level  odor name  \
# 8973    92606.000000       1092.000000  0.555287    8.000000 200.000000
# 2554     9895.000000       1152.000000 -0.278948    8.000000 200.000000
# 7387    62660.000000        854.000000  1.041924    8.000000 200.000000
# 7163    62341.000000        916.000000 -0.557026    8.000000 200.000000
# 16532 6931359.000000       1644.000000 -1.391261    8.000000 287.000000
# 911      7222.000000        115.000000 -0.557026    8.000000 287.000000
# 12953  643731.000000       2119.000000 -0.417987    8.000000 287.000000
# 4569    20995.000000       2538.000000  1.041924    8.000000 287.000000
# 13661 5281516.000000        379.000000  2.293277    8.000000 464.000000
# 3549    13233.000000       1120.000000  0.902885    8.000000 464.000000
# 12881  641832.000000       2235.000000 -0.487506    8.000000 464.000000
# 2381     8842.000000        978.000000  0.277209    8.000000 464.000000
# 9923   106756.000000       2640.000000  0.555287    8.000000 464.000000
# 2178     8375.000000        466.000000 -0.626545    8.000000 464.000000
# 10094  108312.000000        963.000000  0.277209    8.000000 464.000000
# 14270 5355856.000000       2217.000000  1.041924    8.000000 464.000000
# 11887  442368.000000        379.000000  2.293277    8.000000 464.000000
# 6490    61446.000000        654.000000  0.902885    8.000000 464.000000
# 13083 1549778.000000        387.000000  0.624807    8.000000 464.000000
# 16874 9856149.000000        211.000000  1.667601    8.000000 464.000000
# 6509    61450.000000       3157.000000 -0.974143    8.000000 464.000000
# 1273     7651.000000        763.000000  0.346729    8.000000 464.000000
# 5981    61096.000000       2895.000000  0.763846    8.000000 464.000000
# 16298 6438070.000000       2099.000000 -0.278948    8.000000 464.000000
# 464      6184.000000       2598.000000 -0.696065    8.000000 494.000000
#
#            fsp3  small rings  arom rings  ring blocks  arom blocks  ...  \
# 8973  -0.087388     0.200130   -0.631781     0.632666    -0.644741  ...
# 2554   0.229345     0.200130   -0.631781     0.632666    -0.644741  ...
# 7387  -1.054436     0.200130    1.183366     0.632666     1.285620  ...
# 7163  -1.268212     0.200130    1.183366     0.632666     1.285620  ...
# 16532 -0.519433     1.278317    1.183366     0.632666     1.285620  ...
# 911   -2.391380     1.278317    2.998513     0.632666     1.285620  ...
# 12953 -0.727594    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 4569  -0.311273     0.200130    1.183366     0.632666     1.285620  ...
# 13661 -0.644105    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 3549   1.352513     0.200130   -0.631781     0.632666    -0.644741  ...
# 12881  0.817511    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 2381   0.603735    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 9923   1.012193     0.200130   -0.631781     0.632666    -0.644741  ...
# 2178  -1.923393     0.200130    1.183366     0.632666     1.285620  ...
# 10094 -0.519433     0.200130    1.183366     0.632666     1.285620  ...
# 14270  0.015569    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 11887 -0.644105    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 6490  -0.394762     0.200130    1.183366     0.632666     1.285620  ...
# 13083 -0.087388    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 16874  0.603735    -0.878056   -0.631781     0.632666    -0.644741  ...
# 6509  -0.727594     0.200130    1.183366     0.632666     1.285620  ...
# 1273  -0.831300     0.200130    1.183366     0.632666     1.285620  ...
# 5981   1.012193    -0.878056   -0.631781    -1.106175    -0.644741  ...
# 16298  0.229345     0.200130   -0.631781     0.632666    -0.644741  ...
# 464    0.728406    -0.878056   -0.631781    -1.106175    -0.644741  ...
#
#           atsm4     atsm5     natom  arom bond  arom atom      apol     alogp  \
# 8973   0.439700  0.480895  0.544577   0.000000   0.000000  0.608945  0.722196
# 2554   0.255597  0.144180 -0.198182   0.000000   0.000000 -0.212547  0.249833
# 7387   0.347392  0.432488  0.544577   0.000000   0.000000  0.735923  0.567864
# 7163  -0.113121  0.096307 -0.516508   0.000000   0.000000 -0.405350 -0.647635
# 16532 -0.224431 -0.791999 -0.940942   0.000000   0.000000 -0.845452 -1.558636
# 911   -0.296159 -0.839599 -1.577593   0.000000   0.000000 -1.185938 -0.959560
# 12953 -1.034147 -0.768084 -0.516508   0.000000   0.000000 -0.532328  0.211528
# 4569  -0.849270 -0.575249 -0.516508   0.000000   0.000000 -0.315460  0.306181
# 13661 -0.112609  0.048967  1.075120   0.000000   0.000000  1.165596  2.089945
# 3549   0.717920  2.358126  0.120143   0.000000   0.000000  0.559783 -0.214688
# 12881 -0.574145 -0.720210 -0.622616   0.000000   0.000000 -0.813284 -0.267913
# 2381  -0.757737 -0.431902  0.226252   0.000000   0.000000  0.063158  0.416447
# 9923  -0.067223 -0.095721  0.438469   0.000000   0.000000  0.327989  0.605684
# 2178  -0.159530 -0.224522 -1.153159   0.000000   0.000000 -1.044912 -1.428245
# 10094 -0.204916 -0.143594  0.226252   0.000000   0.000000  0.289164  0.174680
# 14270  0.209187  0.576642  1.181228   0.000000   0.000000  1.149470  1.379076
# 11887 -0.112609  0.048967  1.075120   0.000000   0.000000  1.165596  2.089945
# 6490   0.992009  0.961231  1.075120   0.000000   0.000000  1.193546  0.817820
# 13083 -0.343122 -0.047314  0.756794   0.000000   0.000000  0.746787  0.812546
# 16874  0.623803  1.105385  1.499554   0.000000   0.000000  1.469251  1.666227
# 6509  -0.481838 -0.192001 -0.516508   0.000000   0.000000 -0.504377 -1.331857
# 1273   0.116880  0.384067  0.120143   0.000000   0.000000  0.234213  0.044497
# 5981  -0.343633 -0.287748  0.650686   0.000000   0.000000  0.465831  0.966323
# 16298 -0.205428 -0.239875 -0.092074   0.000000   0.000000 -0.129645  0.075585
# 464   -1.448762 -1.200546 -1.047050   0.000000   0.000000 -1.215967 -0.413571
#
#          alogp2       amr      acid
# 8973   0.444875  0.577343 -0.161598
# 2554  -0.019893 -0.343095 -0.161598
# 7387   0.281971  1.185509 -0.161598
# 7163  -0.626199 -0.115391 -0.161598
# 16532 -0.870762 -0.789328 -0.161598
# 911   -0.751998 -0.483534 -0.161598
# 12953 -0.053183 -0.399751 -0.161598
# 4569   0.030275 -0.084142 -0.161598
# 13661  2.357192  1.368033 -0.161598
# 3549  -0.378981  0.872099 -0.161598
# 12881 -0.413918 -1.081532 -0.161598
# 2381   0.132573 -0.121705 -0.161598
# 9923   0.320908 -0.014387 -0.161598
# 2178  -0.858675 -0.669624 -0.161598
# 10094 -0.084575  0.508583 -0.161598
# 14270  1.258183  1.126426 -0.161598
# 11887  2.357192  1.368033 -0.161598
# 6490   0.551194  1.402234 -0.161598
# 13083  0.545221  0.751145 -0.161598
# 16874  1.674734  1.288287 -0.161598
# 6509  -0.844811 -0.358549 -0.161598
# 1273  -0.190602  0.496923 -0.161598
# 5981   0.724451  0.128970 -0.161598
# 16298 -0.165973 -0.233918 -0.161598
# 464   -0.503023 -1.452390 -0.161598
#
# [25 rows x 212 columns]

# %%
count=0
for i in range(1, len(sensorama2_8)):
    if sensorama2_8.iloc[i,4]!= sensorama2_8.iloc[i-1,4]:
        count = count +1
print(count)
# Out:
# 3

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'rings 8', 'rings 9', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.11', 'mden.12', 'mden.13', 'mden.22',
               'mden.23', 'mden.33', 'mlogp', 'atom p', 'atom lc', 'khs.sli', 'khs.ssbe', 'khs.ssssbe', 'khs.ssbh', 'khs.sssb',
               'khs.ssssb', 'khs.sch3', 'khs.dch2', 'khs.ssch2', 'khs.tch', 'khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh3', 'khs.snh2', 'khs.ssnh', 'khs.dnh', 'khs.ssnh.1',
               'khs.aanh', 'khs.tn', 'khs.sssnh', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.ssssn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao', 'khs.sf', 'khs.ssih3', 'khs.sssih2', 'khs.ssssih', 'khs.sssssi', 'khs.sph2',
               'khs.ssph', 'khs.sssp', 'khs.dsssp', 'khs.sssssp', 'khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss', 'khs.ddsss',
               'khs.scl', 'khs.sGeH3', 'khs.ssGeH2', 'khs.sssGeH', 'khs.ssssGe', 'khs.sash2', 'khs.ssash', 'khs.sssas', 'khs.sssdas',
               'khs.sssssas', 'khs.sseh', 'khs.dse', 'khs.ssse', 'khs.aase', 'khs.dssse', 'khs.ddssse', 'khs.sbr', 'khs.ssnh3', 
               'khs.sssnh2', 'khs.ssssnh', 'khs.sssssn', 'khs.si', 'khs.spbh3', 'khs.sspbh2', 'khs.ssspbh', 'khs.sssspb', 'kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'basic group count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom','arom bond', 'arom atom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %% [markdown]
# #### RANDOM FOREST

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  85.71428571428571 %

# %% [markdown]
# ##### Feature Importances

# %%
featureImportances = pd.Series(clf.feature_importances_).sort_values(ascending=False)
sns.barplot(x=round(featureImportances,8), y=featureImportances)
plt.xlabel('Features Importance')
plt.show()

# %%
X = sensorama2_8[[ 'xlogp','fsp3', 'small rings','arom rings','ring blocks','arom blocks','rings 3','rings 4', 'rings 5', 'rings 6',
               'rings 7', 'tpsa efficiency', 'zagreb indices', 'weiner path', 'weiner polarity', 'wtpt.1',
               'wtpt.2', 'wtpt.3', 'wtpt.4', 'wtpt.5', 'molecular weight', 'VAdjMat', 'topoPSA', 'lipinski failures', 'rotatable bonds',
               'topo shape', 'petitjean number', 'mdec.11', 'mdec.12', 'mdec.13', 'mdec.14', 'mdec.22', 'mdec.23', 'mdec.24',
               'mdec.33', 'mdec.34', 'mdec.44', 'mdeo.11', 'mdeo.12', 'mdeo.22', 'mden.22',
               'mden.23', 'mlogp', 'atom p', 'atom lc',
                  'khs.sch3', 'khs.dch2', 'khs.ssch2','khs.dsch', 'khs.aach', 'khs.sssch', 'khs.ddc',
               'khs.tsc', 'khs.dssc', 'khs.aasc', 'khs.aaac', 'khs.ssssc', 'khs.snh2', 'khs.ssnh.1',
               'khs.tn', 'khs.dsn', 'khs.aan', 'khs.sssn', 'khs.dsn.1', 'khs.aasn', 'khs.soh',
               'khs.do', 'khs.sso', 'khs.aao','khs.ssh', 'khs.ds', 'khs.sss', 'khs.aas', 'khs.dsss','kier 1',
               'kier 2', 'hybRatio', 'hbdon', 'hbacc', 'fragc', 'fmf', 'eccen', 'SP.0', 'SP.1', 'SP.2', 'SP.3', 'SP.4', 'SP.5', 'SP.6',
               'SP.7', 'VP.0', 'VP.1', 'VP.2', 'VP.3', 'VP.4', 'VP.5', 'VP.6', 'VP.7', 'SPC.4', 'SPC.5', 'SPC.6', 'VPC.4', 'VPC.5',
               'VPC.6', 'SC.3', 'SC.4', 'SC.5', 'SC.6', 'VC.3', 'VC.4', 'VC.5', 'VC.6', 'SCH.3', 'SCH.4', 'SCH.5', 'SCH.6', 'SCH.7',
               'VCH.3', 'VCH.4', 'VCH.3', 'VCH.4', 'VCH.5', 'VCH.6', 'VCH.7', 'C1SP1', 'C2SP1', 'C1SP2', 'C2SP2', 'C3SP2', 'C1SP3',
               'C2SP3', 'C3SP3', 'C4SP3', 'bpol', 'bond count', 'atsp1', 'atsp2' , 'atsp3', 'atsp4', 'atsp5',
               'atsm1', 'atsm2','atsm3','atsm4','atsm5', 'natom', 'apol','alogp', 'alogp2', 'amr', 'acid']]
y = sensorama2_8['odor name']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
plt.show()
# Out:
# Accuracy:  71.42857142857143 %

# %% [markdown]
# #### SUPPORT VECTOR MACHINE

# %% [markdown]
# ##### rbf Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='rbf') # creating Support Vector Machine model
clf.fit(X_tr, y_tr) # training the Model
y_pr = clf.predict(X_tst) # making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 85.71428571428571 %

# %% [markdown]
# ##### Polynomial Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf = svm.SVC(kernel='poly') # Creating Support Vector Machine Model
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 85.71428571428571 %

# %% [markdown]
# ##### Sigmoid Kernel

# %%
X_tr, X_tst, y_tr, y_tst = train_test_split(X, y, test_size=25/100,random_state=109)
clf=svm.SVC(kernel='sigmoid') # instantiate classifier with sigmoid kernel
clf.fit(X_tr,y_tr) # fit classifier to training set
y_pr = clf.predict(X_tst) # Making Predictions

# Evaluating Prediction Accuracy
print("Accuracy:",metrics.accuracy_score(y_tst, y_pr)*100,"%")
# Out:
# Accuracy: 85.71428571428571 %

# %% [markdown]
# #### DECISION TREE

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test
clf = DecisionTreeClassifier() # Create Decision Tree classifer object
clf = clf.fit(X_train,y_train) # Train Decision Tree Classifer
y_pred = clf.predict(X_test) # Predict the response for test dataset

# how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred)*100,"%")
# Out:
# Accuracy: 37.5 %

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
clf= LogisticRegression( max_iter=100000000)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print('Accuracy: ',metrics.accuracy_score(y_test, y_pred)*100,'%')
# Out:
# Accuracy:  85.71428571428571 %

# %% [markdown]
# #### K-Nearest Neighbor

# %%
# Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
accuracy=[]
for i in range(1,19):
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(X_train, y_train)
    ypred = clf.predict(X_test)
    accuracy.append(metrics.accuracy_score(y_test, ypred))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 19), accuracy, color='orange', linestyle='dashed', marker='o',
         markerfacecolor='green', markersize=10)
plt.title('Looking for the most accurate k value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

# Best accuracy
print("Accuracy:",metrics.accuracy_score(y_test, ypred)*100,"%")
# Out:
# Accuracy: 85.71428571428571 %
