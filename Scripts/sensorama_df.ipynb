# %%
# Importations
import json
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Reading json file
with open('C:/Users/margu/Desktop/TFG/Sensorama_JSON.json') as file:
    sensorama = json.load(file)

# %%
# Separating the odor name and the odor level and adding each value independently in a list.

name=[]
for i in range(0, len(sensorama)):
    subname=[]
    s=sensorama[i]['odour']
    for j in range(0, len(s)):
        subname.append(s[j]['name']) 
    name.append(subname)

level=[]
for i in range(0, len(sensorama)):
    sublevel=[]
    s=sensorama[i]['odour']
    for j in range(0, len(s)):
        sublevel.append(s[j]['level']) 
    level.append(sublevel)

# %%
# Generating a list for each molecular descriptor values

fsp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['Fsp3'])
    fsp3.append(aux)

nsr=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nSmallRings'])
    nsr.append(aux)

nar=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAromRings'])
    nar.append(aux)

nrb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRingBlocks'])
    nrb.append(aux)

nab=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAromBlocks'])
    nab.append(aux)

nr3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings3'])
    nr3.append(aux)

nr4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings4'])
    nr4.append(aux)

nr5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings5'])
    nr5.append(aux)

nr6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings6'])
    nr6.append(aux)

nr7=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings7'])
    nr7.append(aux)

nr8=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings8'])
    nr8.append(aux)

nr9=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRings9'])
    nr9.append(aux)

tpsa=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['tpsaEfficiency'])
    tpsa.append(aux)

zagreb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['Zagreb'])
    zagreb.append(aux)

wpath=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WPATH'])
    wpath.append(aux)

wpol=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WPOL'])
    wpol.append(aux)

wtpt1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WTPT.1'])
    wtpt1.append(aux)

wtpt2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WTPT.2'])
    wtpt2.append(aux)

wtpt3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WTPT.3'])
    wtpt3.append(aux)

wtpt4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WTPT.4'])
    wtpt4.append(aux)

wtpt5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['WTPT.5'])
    wtpt5.append(aux)

mw=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MW'])
    mw.append(aux)

vam=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VAdjMat'])
    vam.append(aux)

tpsa=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['TopoPSA'])
    tpsa.append(aux)

lf=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['LipinskiFailures'])
    lf.append(aux)

nrotb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nRotB'])
    nrotb.append(aux)

ts=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['topoShape'])
    ts.append(aux)

pjn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['PetitjeanNumber'])
    pjn.append(aux)

mdec11=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.11'])
    mdec11.append(aux)

mdec12=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.12'])
    mdec12.append(aux)

mdec13=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.13'])
    mdec13.append(aux)

mdec14=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.14'])
    mdec14.append(aux)

mdec22=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.22'])
    mdec22.append(aux)

mdec23=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.23'])
    mdec23.append(aux)

mdec24=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.24'])
    mdec24.append(aux)

mdec33=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.33'])
    mdec33.append(aux)

mdec34=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.34'])
    mdec34.append(aux)

mdec44=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEC.44'])
    mdec44.append(aux)

mdeo11=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEO.11'])
    mdeo11.append(aux)

mdeo12=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEO.12'])
    mdeo12.append(aux)

mdeo22=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEO.22'])
    mdeo22.append(aux)

mden11=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEN.11'])
    mden11.append(aux)

mden12=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEN.12'])
    mden12.append(aux)

mden13=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEN.13'])
    mden13.append(aux)

mden22=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEN.22'])
    mden22.append(aux)

mden23=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEN.23'])
    mden23.append(aux)

mden33=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MDEN.33'])
    mden33.append(aux)

mlogp=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['MLogP'])
    mlogp.append(aux)

ap=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAtomP'])
    ap.append(aux)

alc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAtomLC'])
    alc.append(aux)

sli=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sLi'])
    sli.append(aux)

ssbe=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssBe'])
    ssbe.append(aux)

ssssbe=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssBe'])
    ssssbe.append(aux)

ssbh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssBH'])
    ssbh.append(aux)

sssb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssB'])
    sssb.append(aux)

ssssb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssB'])
    ssssb.append(aux)

sch3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sCH3'])
    sch3.append(aux)

dch2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dCH2'])
    dch2.append(aux)

ssch2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssCH2'])
    ssch2.append(aux)

tch=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.tCH'])
    tch.append(aux)

dsch=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dsCH'])
    dsch.append(aux)

aach=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaCH'])
    aach.append(aux)

sssch=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssCH'])
    sssch.append(aux)

ddc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ddC'])
    ddc.append(aux)

tsc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.tsC'])
    tsc.append(aux)

dssc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dssC'])
    dssc.append(aux)

aasc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aasC'])
    aasc.append(aux)

aaac=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaaC'])
    aaac.append(aux)

ssssc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssC'])
    ssssc.append(aux)

snh3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sNH3'])
    snh3.append(aux)

snh2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sNH2'])
    snh2.append(aux)

ssnh2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssNH2'])
    ssnh2.append(aux)

dnh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dNH'])
    dnh.append(aux)

ssnh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssNH'])
    ssnh.append(aux)

aanh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaNH'])
    aanh.append(aux)

tn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.tN'])
    tn.append(aux)

sssnh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssNH'])
    sssnh.append(aux)

dsn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dsN'])
    dsn.append(aux)

aan=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaN'])
    aan.append(aux)

sssn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssN'])
    sssn.append(aux)

ddsn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ddsN'])
    ddsn.append(aux)

aasn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aasN'])
    aasn.append(aux)

ssssn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssN'])
    ssssn.append(aux)

soh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sOH'])
    soh.append(aux)

do=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dO'])
    do.append(aux)

sso=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssO'])
    sso.append(aux)

aao=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaO'])
    aao.append(aux)

sff=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sF'])
    sff.append(aux)

ssih3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sSiH3'])
    ssih3.append(aux)

sssih2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssSiH2'])
    sssih2.append(aux)

ssssih=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssSiH'])
    ssssih.append(aux)

sssssi=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssSi'])
    sssssi.append(aux)

sph2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sPH2'])
    sph2.append(aux)

ssph=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssPH'])
    ssph.append(aux)

sssp=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssP'])
    sssp.append(aux)

dsssp=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dsssP'])
    dsssp.append(aux)

sssssp=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssssP'])
    sssssp.append(aux)

ssh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sSH'])
    ssh.append(aux)

ds=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dS'])
    ds.append(aux)

sss=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssS'])
    sss.append(aux)

aas=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaS'])
    aas.append(aux)

dsss=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dssS'])
    dsss.append(aux)

ddsss=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ddssS'])
    ddsss.append(aux)

scl=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sCl'])
    scl.append(aux)

sgeh3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sGeH3'])
    sgeh3.append(aux)

ssgeh2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssGeH2'])
    ssgeh2.append(aux)

sssgeh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssGeH'])
    sssgeh.append(aux)

ssssge=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssGe'])
    ssssge.append(aux)

sash2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sAsH2'])
    sash2.append(aux)

ssash=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssAsH'])
    ssash.append(aux)

sssas=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssAs'])
    sssas.append(aux)

sssdas=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssdAs'])
    sssdas.append(aux)

sssssas=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssssAs'])
    sssssas.append(aux)

sseh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sSeH'])
    sseh.append(aux)

dse=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dSe'])
    dse.append(aux)

ssse=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssSe'])
    ssse.append(aux)

aaSe=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.aaSe'])
    aaSe.append(aux)

dssse=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.dssSe'])
    dssse.append(aux)

ddssse=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ddssSe'])
    ddssse.append(aux)

sbr=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sBr'])
    sbr.append(aux)

ssnh3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sSnH3'])
    ssnh3.append(aux)

sssnh2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssSnH2'])
    sssnh2.append(aux)

ssssnh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssSnH'])
    ssssnh.append(aux)

sssssn=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssSn'])
    sssssn.append(aux)

si=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sI'])
    si.append(aux)

spbh3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sPbH3'])
    spbh3.append(aux)

sspbh2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssPbH2'])
    sspbh2.append(aux)

ssspbh=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.sssPbH'])
    ssspbh.append(aux)

sssspb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['khs.ssssPb'])
    sssspb.append(aux)

kier1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['Kier1'])
    kier1.append(aux)

kier2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['Kier2'])
    kier2.append(aux)

hybratio=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['HybRatio'])
    hybratio.append(aux)

nhbdon=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nHBDon'])
    nhbdon.append(aux) 

nhbacc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nHBAcc'])
    nhbacc.append(aux)

fragc=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['fragC'])
    fragc.append(aux)

fmf=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['FMF'])
    fmf.append(aux)

eccen=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ECCEN'])
    eccen.append(aux)

sp0=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.0'])
    sp0.append(aux)

sp1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.1'])
    sp1.append(aux)

sp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.2'])
    sp2.append(aux)

sp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.3'])
    sp3.append(aux)

sp4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.4'])
    sp4.append(aux)

sp5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.5'])
    sp5.append(aux)

sp6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.6'])
    sp6.append(aux)

sp7=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SP.7'])
    sp7.append(aux)

vp0=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.0'])
    vp0.append(aux)

vp1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.1'])
    vp1.append(aux)

vp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.2'])
    vp2.append(aux)

vp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.3'])
    vp3.append(aux)

vp4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.4'])
    vp4.append(aux)

vp5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.5'])
    vp5.append(aux)

vp6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.6'])
    vp6.append(aux)

vp7=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VP.7'])
    vp7.append(aux)

spc4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SPC.4'])
    spc4.append(aux)

spc5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SPC.5'])
    spc5.append(aux)

spc6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SPC.6'])
    spc6.append(aux)

vpc4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VPC.4'])
    vpc4.append(aux)

vpc5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VPC.5'])
    vpc5.append(aux)

vpc6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VPC.6'])
    vpc6.append(aux)

sc3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SC.3'])
    sc3.append(aux)

sc4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SC.4'])
    sc4.append(aux)

sc5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SC.5'])
    sc5.append(aux)

sc6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SC.6'])
    sc6.append(aux)

vc3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VC.3'])
    vc3.append(aux)

vc4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VC.4'])
    vc4.append(aux)

vc5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VC.5'])
    vc5.append(aux)

vc6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VC.6'])
    vc6.append(aux)

sch3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SCH.3'])
    sch3.append(aux)

sch4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SCH.4'])
    sch4.append(aux)

sch5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SCH.5'])
    sch5.append(aux)

sch6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SCH.6'])
    sch6.append(aux)

sch7=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['SCH.7'])
    sch7.append(aux)

vch3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VCH.3'])
    vch3.append(aux)

vch4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VCH.4'])
    vch4.append(aux)

vch5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VCH.5'])
    vch5.append(aux)

vch6=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VCH.6'])
    vch6.append(aux)

vch7=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['VCH.7'])
    vch7.append(aux)

c1sp1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C1SP1'])
    c1sp1.append(aux)

c2sp1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C2SP1'])
    c2sp1.append(aux)

c1sp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C1SP2'])
    c1sp2.append(aux)

c2sp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C2SP2'])
    c2sp2.append(aux)

c3sp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C3SP2'])
    c3sp2.append(aux)

c1sp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C1SP3'])
    c1sp3.append(aux)

c2sp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C2SP3'])
    c2sp3.append(aux)

c3sp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C3SP3'])
    c3sp3.append(aux)

c4sp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['C4SP3'])
    c4sp3.append(aux)

bpol=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['bpol'])
    bpol.append(aux)

nb=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nB'])
    nb.append(aux)

nbase=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nBase'])
    nbase.append(aux)

atsp1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSp1'])
    atsp1.append(aux)

atsp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSp2'])
    atsp2.append(aux)

atsp3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSp3'])
    atsp3.append(aux)

atsp4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSp4'])
    atsp4.append(aux)

atsp5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSp5'])
    atsp5.append(aux)

atsm1=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSm1'])
    atsm1.append(aux)

atsm2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSm2'])
    atsm2.append(aux)

atsm3=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSm3'])
    atsm3.append(aux)

atsm4=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSm4'])
    atsm4.append(aux)

atsm5=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ATSm5'])
    atsm5.append(aux)

natom=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAtom'])
    natom.append(aux)

narombond=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAromBond'])
    narombond.append(aux)

naaromatom=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['naAromAtom'])
    naaromatom.append(aux)

apol=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['apol'])
    apol.append(aux)

alogp=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ALogP'])
    alogp.append(aux)

alogp2=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['ALogp2'])
    alogp2.append(aux)

amr=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['AMR'])
    amr.append(aux)

acid=[]
for i in range(0, len(sensorama)):
    aux=[]
    s=sensorama[i]['descriptors']
    for j in range(0,len(s)):
        aux.append(s[j]['nAcid'])
    acid.append(aux)

# %%
# Adding each list of odor characteristics and molecular descriptors as a new columns

sensorama_df=pd.DataFrame(sensorama)

sensorama_df.insert(3,"odor name",name,True)

sensorama_df.insert(4, "odor level", level, True)

sensorama_df.insert(5, "fsp3", fsp3, True)

sensorama_df.insert(6, "small rings", nsr, True)

sensorama_df.insert(7, "arom rings", nar, True)

sensorama_df.insert(8, "ring blocks", nrb, True)

sensorama_df.insert(9, "arom blocks", nab, True)

sensorama_df.insert(10, "rings 3", nr3, True)

sensorama_df.insert(11, "rings 4", nr4, True)

sensorama_df.insert(12, "rings 5", nr5, True)

sensorama_df.insert(13, "rings 6", nr6, True)

sensorama_df.insert(14, "rings 7", nr7, True)

sensorama_df.insert(15, "rings 8", nr8, True)

sensorama_df.insert(16, "rings 9", nr9, True)

sensorama_df.insert(17, "tpsa efficiency", tpsa, True)

sensorama_df.insert(18, "zagreb indices", zagreb, True)

sensorama_df.insert(19, "weiner path", wpath, True)

sensorama_df.insert(20, "weiner polarity", wpol, True)

sensorama_df.insert(21, "wtpt.1", wtpt1, True)

sensorama_df.insert(22, "wtpt.2", wtpt2, True)

sensorama_df.insert(23, "wtpt.3", wtpt3, True)

sensorama_df.insert(24, "wtpt.4", wtpt4, True)

sensorama_df.insert(25, "wtpt.5", wtpt5, True)

sensorama_df.insert(26, "molecular weight", mw, True)

sensorama_df.insert(27, "VAdjMat", vam, True)

sensorama_df.insert(28, "topoPSA", tpsa, True)

sensorama_df.insert(29, "lipinski failures", lf, True)

sensorama_df.insert(30, "rotatable bonds", nrotb, True)

sensorama_df.insert(31, "topo shape", ts, True)

sensorama_df.insert(32, "petitjean number", pjn, True)

sensorama_df.insert(33, "mdec.11", mdec11, True)

sensorama_df.insert(34, "mdec.12", mdec12, True)

sensorama_df.insert(35, "mdec.13", mdec13, True)

sensorama_df.insert(36, "mdec.14", mdec14, True)

sensorama_df.insert(37, "mdec.22", mdec22, True)

sensorama_df.insert(38, "mdec.23", mdec23, True)

sensorama_df.insert(39, "mdec.24", mdec24, True)

sensorama_df.insert(40, "mdec.33", mdec33, True)

sensorama_df.insert(41, "mdec.34", mdec34, True)

sensorama_df.insert(42, "mdec.44", mdec44, True)

sensorama_df.insert(43, "mdeo.11", mdeo11, True)

sensorama_df.insert(44, "mdeo.12", mdeo12, True)

sensorama_df.insert(45, "mdeo.22", mdeo22, True)

sensorama_df.insert(46, "mden.11", mden11, True)

sensorama_df.insert(47, "mden.12", mden12, True)

sensorama_df.insert(48, "mden.13", mden13, True)

sensorama_df.insert(49, "mden.22", mden22, True)

sensorama_df.insert(50, "mden.23", mden23, True)

sensorama_df.insert(51, "mden.33", mden33, True)

sensorama_df.insert(52, "mlogp", mlogp, True)

sensorama_df.insert(53, "atom p", ap, True)

sensorama_df.insert(54, "atom lc", alc, True)

sensorama_df.insert(55, "khs.sli", sli, True)

sensorama_df.insert(56, "khs.ssbe", ssbe, True)

sensorama_df.insert(57, "khs.ssssbe", ssssbe, True)

sensorama_df.insert(58, "khs.ssbh", ssbh, True)

sensorama_df.insert(59, "khs.sssb", sssb, True)

sensorama_df.insert(60, "khs.ssssb", ssssb, True)

sensorama_df.insert(61, "khs.sch3", sch3, True)

sensorama_df.insert(62, "khs.dch2", dch2, True)

sensorama_df.insert(63, "khs.ssch2", ssch2, True)

sensorama_df.insert(64, "khs.tch", tch, True)

sensorama_df.insert(65, "khs.dsch", dsch, True)

sensorama_df.insert(66, "khs.aach", aach, True)

sensorama_df.insert(67, "khs.sssch", sssch, True)

sensorama_df.insert(68, "khs.ddc", ddc, True)

sensorama_df.insert(69, "khs.tsc", tsc, True)

sensorama_df.insert(70, "khs.dssc", dssc, True)

sensorama_df.insert(71, "khs.aasc", aasc, True)

sensorama_df.insert(72, "khs.aaac", aaac, True)

sensorama_df.insert(73, "khs.ssssc", ssssc, True)

sensorama_df.insert(74, "khs.snh3", snh3, True)

sensorama_df.insert(75, "khs.snh2", snh2, True)

sensorama_df.insert(76, "khs.ssnh", ssnh2, True)

sensorama_df.insert(77, "khs.dnh", dnh, True)

sensorama_df.insert(78, "khs.ssnh", ssnh, True)

sensorama_df.insert(79, "khs.aanh", aanh, True)

sensorama_df.insert(80, "khs.tn", tn, True)

sensorama_df.insert(81, "khs.sssnh", sssnh, True)

sensorama_df.insert(82, "khs.dsn", dsn, True)

sensorama_df.insert(83, "khs.aan", aan, True)

sensorama_df.insert(84, "khs.sssn", sssn, True)

sensorama_df.insert(85, "khs.dsn", dsn, True)

sensorama_df.insert(86, "khs.aasn", aasn, True)

sensorama_df.insert(87, "khs.ssssn", ssssn, True)

sensorama_df.insert(88, "khs.soh", soh, True)

sensorama_df.insert(89, "khs.do", do, True)

sensorama_df.insert(90, "khs.sso", sso, True)

sensorama_df.insert(91, "khs.aao", aao, True)

sensorama_df.insert(92, "khs.sf", sff, True)

sensorama_df.insert(93, "khs.ssih3", ssih3, True)

sensorama_df.insert(94, "khs.sssih2", sssih2, True)

sensorama_df.insert(95, "khs.ssssih", ssssih, True)

sensorama_df.insert(96, "khs.sssssi", sssssi, True)

sensorama_df.insert(97, "khs.sph2", sph2, True)

sensorama_df.insert(98, "khs.ssph", ssph, True)

sensorama_df.insert(99, "khs.sssp", sssp, True)

sensorama_df.insert(100, "khs.dsssp", dsssp, True)

sensorama_df.insert(101, "khs.sssssp", sssssp, True)

sensorama_df.insert(102, "khs.ssh", ssh, True)

sensorama_df.insert(103, "khs.ds", ds, True)

sensorama_df.insert(104, "khs.sss", sss, True)

sensorama_df.insert(105, "khs.aas", aas, True)

sensorama_df.insert(106, "khs.dsss", dsss, True)

sensorama_df.insert(107, "khs.ddsss", ddsss, True)

sensorama_df.insert(108, "khs.scl", scl, True)

sensorama_df.insert(109, "khs.sGeH3", sgeh3, True)

sensorama_df.insert(110, "khs.ssGeH2", ssgeh2, True)

sensorama_df.insert(111, "khs.sssGeH", sssgeh, True)

sensorama_df.insert(112, "khs.ssssGe", ssssge, True)

sensorama_df.insert(113, "khs.sash2", sash2, True)

sensorama_df.insert(114, "khs.ssash", ssash, True)

sensorama_df.insert(115, "khs.sssas", sssas, True)

sensorama_df.insert(116, "khs.sssdas", sssdas, True)

sensorama_df.insert(117, "khs.sssssas", sssssas, True)

sensorama_df.insert(118, "khs.sseh", sseh, True)

sensorama_df.insert(119, "khs.dse", dse, True)

sensorama_df.insert(120, "khs.ssse", ssse, True)

sensorama_df.insert(121, "khs.aase", aaSe, True)

sensorama_df.insert(122, "khs.dssse", dssse, True)

sensorama_df.insert(123, "khs.ddssse", ddssse, True)

sensorama_df.insert(124, "khs.sbr", sbr, True)

sensorama_df.insert(125, "khs.ssnh3", ssnh3, True)

sensorama_df.insert(126, "khs.sssnh2", sssnh2, True)

sensorama_df.insert(127, "khs.ssssnh", ssssnh, True)

sensorama_df.insert(128, "khs.sssssn", sssssn, True)

sensorama_df.insert(129, "khs.si", si, True)

sensorama_df.insert(130, "khs.spbh3", spbh3, True)

sensorama_df.insert(131, "khs.sspbh2", sspbh2, True)

sensorama_df.insert(132, "khs.ssspbh", ssspbh, True)

sensorama_df.insert(133, "khs.sssspb", sssspb, True)

sensorama_df.insert(134, "kier 1", kier1, True)

sensorama_df.insert(135, "kier 2", kier2, True)

sensorama_df.insert(136, "hybRatio", hybratio, True)

sensorama_df.insert(137, "hbdon", nhbdon, True)

sensorama_df.insert(138, "hbacc", nhbacc, True)

sensorama_df.insert(139, "fragc", fragc, True)

sensorama_df.insert(140, "fmf", fmf, True)

sensorama_df.insert(141, "eccen", eccen, True)

sensorama_df.insert(142, "SP.0", sp0, True)

sensorama_df.insert(143, "SP.1", sp1, True)

sensorama_df.insert(144, "SP.2", sp2, True)

sensorama_df.insert(145, "SP.3", sp3, True)

sensorama_df.insert(146, "SP.4", sp4, True)

sensorama_df.insert(147, "SP.5", sp5, True)

sensorama_df.insert(148, "SP.6", sp6, True)

sensorama_df.insert(149, "SP.7", sp7, True)

sensorama_df.insert(150, "VP.0", vp0, True)

sensorama_df.insert(151, "VP.1", vp1, True)

sensorama_df.insert(152, "VP.2", vp2, True)

sensorama_df.insert(153, "VP.3", vp3, True)

sensorama_df.insert(154, "VP.4", vp4, True)

sensorama_df.insert(155, "VP.5", vp5, True)

sensorama_df.insert(156, "VP.6", vp6, True)

sensorama_df.insert(157, "VP.7", vp7, True)

sensorama_df.insert(158, "SPC.4", spc4, True)

sensorama_df.insert(159, "SPC.5", spc5, True)

sensorama_df.insert(160, "SPC.6", spc6, True)

sensorama_df.insert(161, "VPC.4", vpc4, True)

sensorama_df.insert(162, "VPC.5", vpc5, True)

sensorama_df.insert(163, "VPC.6", vpc6, True)

sensorama_df.insert(164, "SC.3", sc3, True)

sensorama_df.insert(165, "SC.4", sc4, True)

sensorama_df.insert(166, "SC.5", sc5, True)

sensorama_df.insert(167, "SC.6", sc6, True)

sensorama_df.insert(168, "VC.3", vc3, True)

sensorama_df.insert(169, "VC.4", vc4, True)

sensorama_df.insert(170, "VC.5", vc5, True)

sensorama_df.insert(171, "VC.6", vc6, True)

sensorama_df.insert(172, "SCH.3", sch3, True)

sensorama_df.insert(173, "SCH.4", sch4, True)

sensorama_df.insert(174, "SCH.5", sch5, True)

sensorama_df.insert(175, "SCH.6", sch6, True)

sensorama_df.insert(176, "SCH.7", sch7, True)

sensorama_df.insert(177, "VCH.3", vch3, True)

sensorama_df.insert(178, "VCH.4", vch4, True)

sensorama_df.insert(179, "VCH.5", vch5, True)

sensorama_df.insert(180, "VCH.6", vch6, True)

sensorama_df.insert(181, "VCH.7", vch7, True)

sensorama_df.insert(182, "C1SP1", c1sp1, True)

sensorama_df.insert(183, "C2SP1", c2sp1, True)

sensorama_df.insert(184, "C1SP2", c1sp2, True)

sensorama_df.insert(185, "C2SP2", c2sp2, True)

sensorama_df.insert(186, "C3SP2", c3sp2, True)

sensorama_df.insert(187, "C1SP3", c1sp3, True)

sensorama_df.insert(188, "C2SP3", c2sp3, True)

sensorama_df.insert(189, "C3SP3", c3sp3, True)

sensorama_df.insert(190, "C4SP3", c4sp3, True)

sensorama_df.insert(191, "bpol", bpol, True)

sensorama_df.insert(192, "bond count", nb, True)

sensorama_df.insert(193, "basic group count", nbase, True)

sensorama_df.insert(194, "atsp1", atsp1, True)

sensorama_df.insert(195, "atsp2", atsp2, True)

sensorama_df.insert(196, "atsp3", atsp3, True)

sensorama_df.insert(197, "atsp4", atsp4, True)

sensorama_df.insert(198, "atsp5", atsp5, True)

sensorama_df.insert(199, "atsm1", atsm1, True)

sensorama_df.insert(200, "atsm2", atsm2, True)

sensorama_df.insert(201, "atsm3", atsm3, True)

sensorama_df.insert(202, "atsm4", atsm4, True)

sensorama_df.insert(203, "atsm5", atsm5, True)

sensorama_df.insert(204, "natom", natom, True)

sensorama_df.insert(205, "arom bond", narombond, True)

sensorama_df.insert(206, "arom atom", naaromatom, True)

sensorama_df.insert(207, "apol", apol, True)

sensorama_df.insert(208, "alogp", alogp, True)

sensorama_df.insert(209, "alogp2", alogp2, True)

sensorama_df.insert(210, "amr", amr, True)

sensorama_df.insert(211, "acid", acid, True)

# %%
# Deleting the columns that contain the odor and the descriptors dictionaries
sensorama_df= sensorama_df.drop(['odour'], axis=1)
sensorama_df= sensorama_df.drop(['descriptors'], axis=1)

# %%
sensorama_df=pd.DataFrame(sensorama_df.dropna()) # Deleting NaNs values

# %%
sensorama_df=sensorama_df.reset_index() # Reseting the indexes

# %%
# Separating the odor names of molecules that have various assigned
name=['fishy']
for i in range(1, len(sensorama_df)):
    if sensorama_df['cid'][i] != sensorama_df['cid'][i-1]:
        s=sensorama_df['odor name'][i]
        for j in range(0, len(s)):
            name.append(s[j])

# %%
# Separating the odor levels of molecules that have various assigned
level=[1]
for i in range(1, len(sensorama_df)):
    if sensorama_df['cid'][i] != sensorama_df['cid'][i-1]:
        s=sensorama_df['odor level'][i]
        for j in range(0, len(s)):
            level.append(s[j])

# %%
# Generating as many rows as odors associated to a molecule.
l=len(sensorama_df)
for i in range(0, l):
    if (len(sensorama_df['odor level'][i]) > 1):
        s= sensorama_df.loc[i,:]
        for j in range(1, len(sensorama_df['odor level'][i])):
            sensorama_df = sensorama_df.append(s, ignore_index = True)

# %%
sensorama_df=sensorama_df.sort_values('index') #sorting the data frame by index

# %%
# Deleting the columns with odor information in list format
sensorama_df= sensorama_df.drop('odor level', axis=1)
sensorama_df= sensorama_df.drop('odor name', axis=1)

# %%
# Adding the lists with odor levels and names values separated individually
sensorama_df.insert(4,'odor level', level)
sensorama_df.insert(5,'odor name', name)

# %%
sensorama_df= sensorama_df.drop('index', axis=1) # Deleting the column index because now it's innecessary.

# %%
# Saving a safety copy in CSV:
sensorama_df.to_csv('sensorama_df.csv', header=True, index=False)

# %%
# Reloading the data
def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset
sensorama = load_dataset('sensorama_df.csv')
nRow, nCol = sensorama.shape
print(f'sensorama_df has {nRow} rows and {nCol} columns')
# Out:
# sensorama_df has 17994 rows and 212 columns

# %%
#Deleting innecessary claudators
for i in range(0,17994):
    for j in range(5, 212):
        sensorama.iloc[i,j]=(str(sensorama.iloc[i,j])).replace('[','').replace(']','')

# %%
# Taking a look at the tpye of data
sensorama.dtypes
# Out:
# cid                   int64
# canonical_smiles     object
# xlogp               float64
# odor level            int64
# odor name            object
#                      ...
# apol                 object
# alogp                object
# alogp2               object
# amr                  object
# acid                 object
# Length: 212, dtype: object

# %%
# Tranforming object data to float 
sensorama['fsp3']=sensorama['fsp3'].astype(float)
sensorama['small rings']=sensorama['small rings'].astype(float)
sensorama['arom rings']=sensorama['arom rings'].astype(float)
sensorama['ring blocks']=sensorama['ring blocks'].astype(float)
sensorama['arom blocks']=sensorama['arom blocks'].astype(float)
sensorama['rings 3']=sensorama['rings 3'].astype(float)
sensorama['rings 4']=sensorama['rings 4'].astype(float)
sensorama['rings 5']=sensorama['rings 5'].astype(float)
sensorama['rings 6']=sensorama['rings 6'].astype(float)
sensorama['rings 7']=sensorama['rings 7'].astype(float)
sensorama['rings 8']=sensorama['rings 8'].astype(float)
sensorama['rings 9']=sensorama['rings 9'].astype(float)
sensorama['tpsa efficiency']=sensorama['tpsa efficiency'].astype(float)
sensorama['zagreb indices']=sensorama['zagreb indices'].astype(float)
sensorama['weiner path']=sensorama['weiner path'].astype(float)
sensorama['weiner polarity']=sensorama['weiner polarity'].astype(float)
sensorama['wtpt.1']=sensorama['wtpt.1'].astype(float)
sensorama['wtpt.2']=sensorama['wtpt.2'].astype(float)
sensorama['wtpt.3']=sensorama['wtpt.3'].astype(float)
sensorama['wtpt.4']=sensorama['wtpt.4'].astype(float)
sensorama['wtpt.5']=sensorama['wtpt.5'].astype(float)
sensorama['molecular weight']=sensorama['molecular weight'].astype(float)
sensorama['VAdjMat']=sensorama['VAdjMat'].astype(float)
sensorama['topoPSA']=sensorama['topoPSA'].astype(float)
sensorama['lipinski failures']=sensorama['lipinski failures'].astype(float)
sensorama['rotatable bonds']=sensorama['rotatable bonds'].astype(float)
sensorama['topo shape']=sensorama['topo shape'].astype(float)
sensorama['petitjean number']=sensorama['petitjean number'].astype(float)
sensorama['mdec.11']=sensorama['mdec.11'].astype(float)
sensorama['mdec.12']=sensorama['mdec.12'].astype(float)
sensorama['mdec.13']=sensorama['mdec.13'].astype(float)
sensorama['mdec.14']=sensorama['mdec.14'].astype(float)
sensorama['mdec.22']=sensorama['mdec.22'].astype(float)
sensorama['mdec.23']=sensorama['mdec.23'].astype(float)
sensorama['mdec.24']=sensorama['mdec.24'].astype(float)
sensorama['mdec.33']=sensorama['mdec.33'].astype(float)
sensorama['mdec.34']=sensorama['mdec.34'].astype(float)
sensorama['mdec.44']=sensorama['mdec.44'].astype(float)
sensorama['mdeo.11']=sensorama['mdeo.11'].astype(float)
sensorama['mdeo.12']=sensorama['mdeo.12'].astype(float)
sensorama['mdeo.22']=sensorama['mdeo.22'].astype(float)
sensorama['mden.11']=sensorama['mden.11'].astype(float)
sensorama['mden.12']=sensorama['mden.12'].astype(float)
sensorama['mden.13']=sensorama['mden.13'].astype(float)
sensorama['mden.22']=sensorama['mden.22'].astype(float)
sensorama['mden.23']=sensorama['mden.23'].astype(float)
sensorama['mden.33']=sensorama['mden.33'].astype(float)
sensorama['mlogp']=sensorama['mlogp'].astype(float)
sensorama['atom p']=sensorama['atom p'].astype(float)
sensorama['atom lc']=sensorama['atom lc'].astype(float)
sensorama['khs.sli']=sensorama['khs.sli'].astype(float)
sensorama['khs.ssbe']=sensorama['khs.ssbe'].astype(float)
sensorama['khs.ssssbe']=sensorama['khs.ssssbe'].astype(float)
sensorama['khs.ssbh']=sensorama['khs.ssbh'].astype(float)
sensorama['khs.sssb']=sensorama['khs.sssb'].astype(float)
sensorama['khs.ssssb']=sensorama['khs.ssssb'].astype(float)
sensorama['khs.sch3']=sensorama['khs.sch3'].astype(float)
sensorama['khs.dch2']=sensorama['khs.dch2'].astype(float)
sensorama['khs.ssch2']=sensorama['khs.ssch2'].astype(float)
sensorama['khs.tch']=sensorama['khs.tch'].astype(float)
sensorama['khs.dsch']=sensorama['khs.dsch'].astype(float)
sensorama['khs.aach']=sensorama['khs.aach'].astype(float)
sensorama['khs.sssch']=sensorama['khs.sssch'].astype(float)
sensorama['khs.ddc']=sensorama['khs.ddc'].astype(float)
sensorama['khs.tsc']=sensorama['khs.tsc'].astype(float)
sensorama['khs.dssc']=sensorama['khs.dssc'].astype(float)
sensorama['khs.aasc']=sensorama['khs.aasc'].astype(float)
sensorama['khs.aaac']=sensorama['khs.aaac'].astype(float)
sensorama['khs.ssssc']=sensorama['khs.ssssc'].astype(float)
sensorama['khs.snh3']=sensorama['khs.snh3'].astype(float)
sensorama['khs.snh2']=sensorama['khs.snh2'].astype(float)
sensorama['khs.ssnh']=sensorama['khs.ssnh'].astype(float)
sensorama['khs.dnh']=sensorama['khs.dnh'].astype(float)
sensorama['khs.ssnh']=sensorama['khs.ssnh'].astype(float)
sensorama['khs.aanh']=sensorama['khs.aanh'].astype(float)
sensorama['khs.tn']=sensorama['khs.tn'].astype(float)
sensorama['khs.sssnh']=sensorama['khs.sssnh'].astype(float)
sensorama['khs.dsn']=sensorama['khs.dsn'].astype(float)
sensorama['khs.aan']=sensorama['khs.aan'].astype(float)
sensorama['khs.sssn']=sensorama['khs.sssn'].astype(float)
sensorama['khs.dsn']=sensorama['khs.dsn'].astype(float)
sensorama['khs.aasn']=sensorama['khs.aasn'].astype(float)
sensorama['khs.ssssn']=sensorama['khs.ssssn'].astype(float)
sensorama['khs.soh']=sensorama['khs.soh'].astype(float)
sensorama['khs.do']=sensorama['khs.do'].astype(float)
sensorama['khs.sso']=sensorama['khs.sso'].astype(float)
sensorama['khs.aao']=sensorama['khs.aao'].astype(float)
sensorama['khs.sf']=sensorama['khs.sf'].astype(float)
sensorama['khs.ssih3']=sensorama['khs.ssih3'].astype(float)
sensorama['khs.sssih2']=sensorama['khs.sssih2'].astype(float)
sensorama['khs.ssssih']=sensorama['khs.ssssih'].astype(float)
sensorama['khs.sssssi']=sensorama['khs.sssssi'].astype(float)
sensorama['khs.sph2']=sensorama['khs.sph2'].astype(float)
sensorama['khs.ssph']=sensorama['khs.ssph'].astype(float)
sensorama['khs.sssp']=sensorama['khs.sssp'].astype(float)
sensorama['khs.dsssp']=sensorama['khs.dsssp'].astype(float)
sensorama['khs.sssssp']=sensorama['khs.sssssp'].astype(float)
sensorama['khs.ssh']=sensorama['khs.ssh'].astype(float)
sensorama['khs.ds']=sensorama['khs.ds'].astype(float)
sensorama['khs.sss']=sensorama['khs.sss'].astype(float)
sensorama['khs.aas']=sensorama['khs.aas'].astype(float)
sensorama['khs.dsss']=sensorama['khs.dsss'].astype(float)
sensorama['khs.ddsss']=sensorama['khs.ddsss'].astype(float)
sensorama['khs.scl']=sensorama['khs.scl'].astype(float)
sensorama['khs.sGeH3']=sensorama['khs.sGeH3'].astype(float)
sensorama['khs.ssGeH2']=sensorama['khs.ssGeH2'].astype(float)
sensorama['khs.sssGeH']=sensorama['khs.sssGeH'].astype(float)
sensorama['khs.ssssGe']=sensorama['khs.ssssGe'].astype(float)
sensorama['khs.sash2']=sensorama['khs.sash2'].astype(float)
sensorama['khs.ssash']=sensorama['khs.ssash'].astype(float)
sensorama['khs.sssas']=sensorama['khs.sssas'].astype(float)
sensorama['khs.sssdas']=sensorama['khs.sssdas'].astype(float)
sensorama['khs.sssssas']=sensorama['khs.sssssas'].astype(float)
sensorama['khs.sseh']=sensorama['khs.sseh'].astype(float)
sensorama['khs.dse']=sensorama['khs.dse'].astype(float)
sensorama['khs.ssse']=sensorama['khs.ssse'].astype(float)
sensorama['khs.aase']=sensorama['khs.aase'].astype(float)
sensorama['khs.dssse']=sensorama['khs.dssse'].astype(float)
sensorama['khs.ddssse']=sensorama['khs.ddssse'].astype(float)
sensorama['khs.sbr']=sensorama['khs.sbr'].astype(float)
sensorama['khs.ssnh3']=sensorama['khs.ssnh3'].astype(float)
sensorama['khs.sssnh2']=sensorama['khs.sssnh2'].astype(float)
sensorama['khs.ssssnh']=sensorama['khs.ssssnh'].astype(float)
sensorama['khs.sssssn']=sensorama['khs.sssssn'].astype(float)
sensorama['khs.si']=sensorama['khs.si'].astype(float)
sensorama['khs.spbh3']=sensorama['khs.spbh3'].astype(float)
sensorama['khs.sspbh2']=sensorama['khs.sspbh2'].astype(float)
sensorama['khs.ssspbh']=sensorama['khs.ssspbh'].astype(float)
sensorama['khs.sssspb']=sensorama['khs.sssspb'].astype(float)
sensorama['kier 1']=sensorama['kier 1'].astype(float)
sensorama['kier 2']=sensorama['kier 2'].astype(float)
sensorama['hybRatio']=sensorama['hybRatio'].astype(float)
sensorama['hbdon']=sensorama['hbdon'].astype(float)
sensorama['hbacc']=sensorama['hbacc'].astype(float)
sensorama['fragc']=sensorama['fragc'].astype(float)
sensorama['fmf']=sensorama['fmf'].astype(float)
sensorama['eccen']=sensorama['eccen'].astype(float)
sensorama['SP.0']=sensorama['SP.0'].astype(float)
sensorama['SP.1']=sensorama['SP.1'].astype(float)
sensorama['SP.2']=sensorama['SP.2'].astype(float)
sensorama['SP.3']=sensorama['SP.3'].astype(float)
sensorama['SP.4']=sensorama['SP.4'].astype(float)
sensorama['SP.5']=sensorama['SP.5'].astype(float)
sensorama['SP.6']=sensorama['SP.6'].astype(float)
sensorama['SP.7']=sensorama['SP.7'].astype(float)
sensorama['VP.0']=sensorama['VP.0'].astype(float)
sensorama['VP.1']=sensorama['VP.1'].astype(float)
sensorama['VP.2']=sensorama['VP.2'].astype(float)
sensorama['VP.3']=sensorama['VP.3'].astype(float)
sensorama['VP.4']=sensorama['VP.4'].astype(float)
sensorama['VP.5']=sensorama['VP.5'].astype(float)
sensorama['VP.6']=sensorama['VP.6'].astype(float)
sensorama['VP.7']=sensorama['VP.7'].astype(float)
sensorama['SPC.4']=sensorama['SPC.4'].astype(float)
sensorama['SPC.5']=sensorama['SPC.5'].astype(float)
sensorama['SPC.6']=sensorama['SPC.6'].astype(float)
sensorama['VPC.4']=sensorama['VPC.4'].astype(float)
sensorama['VPC.5']=sensorama['VPC.5'].astype(float)
sensorama['VPC.6']=sensorama['VPC.6'].astype(float)
sensorama['SC.3']=sensorama['SC.3'].astype(float)
sensorama['SC.4']=sensorama['SC.4'].astype(float)
sensorama['SC.5']=sensorama['SC.5'].astype(float)
sensorama['SC.6']=sensorama['SC.6'].astype(float)
sensorama['VC.3']=sensorama['VC.3'].astype(float)
sensorama['VC.4']=sensorama['VC.4'].astype(float)
sensorama['VC.5']=sensorama['VC.5'].astype(float)
sensorama['VC.6']=sensorama['VC.6'].astype(float)
sensorama['SCH.3']=sensorama['SCH.3'].astype(float)
sensorama['SCH.4']=sensorama['SCH.4'].astype(float)
sensorama['SCH.5']=sensorama['SCH.5'].astype(float)
sensorama['SCH.6']=sensorama['SCH.6'].astype(float)
sensorama['SCH.7']=sensorama['SCH.7'].astype(float)
sensorama['VCH.3']=sensorama['VCH.3'].astype(float)
sensorama['VCH.4']=sensorama['VCH.4'].astype(float)
sensorama['VCH.5']=sensorama['VCH.5'].astype(float)
sensorama['VCH.6']=sensorama['VCH.6'].astype(float)
sensorama['VCH.7']=sensorama['VCH.7'].astype(float)
sensorama['C1SP1']=sensorama['C1SP1'].astype(float)
sensorama['C2SP1']=sensorama['C2SP1'].astype(float)
sensorama['C1SP2']=sensorama['C1SP2'].astype(float)
sensorama['C2SP2']=sensorama['C2SP2'].astype(float)
sensorama['C3SP2']=sensorama['C3SP2'].astype(float)
sensorama['C1SP3']=sensorama['C1SP3'].astype(float)
sensorama['C2SP3']=sensorama['C2SP3'].astype(float)
sensorama['C3SP3']=sensorama['C3SP3'].astype(float)
sensorama['C4SP3']=sensorama['C4SP3'].astype(float)
sensorama['bpol']=sensorama['bpol'].astype(float)
sensorama['bond count']=sensorama['bond count'].astype(float)
sensorama['basic group count']=sensorama['basic group count'].astype(float)
sensorama['atsp1']=sensorama['atsp1'].astype(float)
sensorama['atsp2']=sensorama['atsp2'].astype(float)
sensorama['atsp3']=sensorama['atsp3'].astype(float)
sensorama['atsp4']=sensorama['atsp4'].astype(float)
sensorama['atsp5']=sensorama['atsp5'].astype(float)
sensorama['atsm1']=sensorama['atsm1'].astype(float)
sensorama['atsm2']=sensorama['atsm2'].astype(float)
sensorama['atsm3']=sensorama['atsm3'].astype(float)
sensorama['atsm4']=sensorama['atsm4'].astype(float)
sensorama['atsm5']=sensorama['atsm5'].astype(float)
sensorama['natom']=sensorama['natom'].astype(float)
sensorama['arom bond']=sensorama['arom bond'].astype(float)
sensorama['arom atom']=sensorama['arom atom'].astype(float)
sensorama['apol']=sensorama['apol'].astype(float)
sensorama['alogp']=sensorama['alogp'].astype(float)
sensorama['alogp2']=sensorama['alogp2'].astype(float)
sensorama['amr']=sensorama['amr'].astype(float)
sensorama['acid']=sensorama['acid'].astype(float)

# %%
# Supervising the data has changed
sensorama.dtypes
# Out:
# cid                   int64
# canonical_smiles     object
# xlogp               float64
# odor level            int64
# odor name            object
#                      ...
# apol                float64
# alogp               float64
# alogp2              float64
# amr                 float64
# acid                float64
# Length: 212, dtype: object

# %%
# Saving data frame in CSV:
sensorama.to_csv('sensorama_df.csv', header=True, index=False)
